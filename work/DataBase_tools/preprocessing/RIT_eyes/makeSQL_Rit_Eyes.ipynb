# %% [markdown]
# # SQL 작성

# %%
import sys
import os
import pandas as pd
import cv2
import pickle
import json
sys.path.append('../../src')
import DISData as DD

# %% [markdown]
# ## SQL 연결

# %%
doUT = DD.SQL()
# Out:
# host:  192.168.0.201
# user:  diadmin
# password:  ········
# SQL connection done

# %% [markdown]
# ## query 작성

# %%
# query 실행
query1 = (f'''CREATE TABLE IF NOT EXISTS RIT_Eyes_s_general_info (
        id INT(11) NOT NULL AUTO_INCREMENT primary key,
        img_dir VARCHAR(100) NOT NULL,
        img_format VARCHAR(10) NOT NULL,
        img_width INT(11) NOT NULL,
        img_height INT(11) NOT NULL,
        color_space VARCHAR(10) NOT NULL,
        label_dir VARCHAR(100) NOT NULL,
        label_format VARCHAR(10) NOT NULL,
        camera_3d_center VARCHAR(200) NOT NULL,
        camera_distance VARCHAR(200) NOT NULL,
        iris_loc VARCHAR(200) NOT NULL,
        eye_loc VARCHAR(200) NOT NULL,
        gaze_angle_az VARCHAR(200) NOT NULL,
        gaze_angle_el VARCHAR(200) NOT NULL,
        ortho_scale VARCHAR(200) NOT NULL,
        cam_az VARCHAR(200) NOT NULL,
        cam_el VARCHAR(200) NOT NULL,
        glasses VARCHAR(200) NOT NULL,
        pupil VARCHAR(200) NOT NULL,
        eye_lid VARCHAR(200) NOT NULL,
        iris_rot VARCHAR(200) NOT NULL,
        left_corner VARCHAR(200) NOT NULL,
        right_corner VARCHAR(200) NOT NULL,
        sclera VARCHAR(200) NOT NULL)''')

# %%
query2 = (f'''INSERT INTO RIT_Eyes_s_general_info 
        (img_dir, img_format, img_width, img_height, color_space,
          label_dir, label_format, camera_3d_center, camera_distance,
          iris_loc, eye_loc, gaze_angle_az, gaze_angle_el, ortho_scale, cam_az, cam_el,
          glasses, pupil, eye_lid, iris_rot, left_corner, right_corner, sclera) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''')

# %% [markdown]
# ## query 실행

# %%
try:
    doUT.create_table(query1)
except Exception as e:
    print(f"Error during table creation: {e}")
# Out:
# create table done

# %%
label_path = []
label_name= []

# label 경로
label_path = 'Z:\\RIT_Eyes_s_general\\data\\labeldata'
image_path = 'Z:\\RIT_Eyes_s_general\\data\\rawdata'

value_list1 = []
error_list = []
count = 0

data_names = os.listdir(image_path)
for data_name in data_names:
    image_path1 = os.path.join(image_path,data_name) 
    for accesory in os.listdir(image_path1):
        image_path2 = os.path.join(image_path1,accesory)
        for image_name in os.listdir(image_path2):
            image = os.path.join(image_path2,image_name)
            # print(image_path1)
            # print(image_path2)
            # print(image)
            label_path = image_path1.replace("rawdata","labeldata")
            label_name = os.listdir(label_path)
            # print(label_name)
            # Check if the list is empty
            if not label_name:
                print(f"No files found in {label_path}")
                continue  # Skip to the next iteration of the loop

            label = os.path.join(label_path,str(label_name[0]).replace('[','').replace(']','').replace("'",'').replace("'",''))
            try:
                with open(label, 'rb') as f:
                    text = pickle.load(f)
                    img_dir = image
                    img_format = 'tif'
                    image = cv2.imread(img_dir)
                    img_width = image.shape[1]
                    img_height = image.shape[0]
                    color_check = img_dir.split('\\')[-2]
                    if color_check == 'synthetic':
                        color_space = 'IR'
                    else:
                        color_space = 'SEGMENT'
                    label_dir = label
                    label_format = 'p'
                    camera_3d_center = str(text["camera_3d_center"][count])
                    camera_distance = str(text["camera_distance"][count])
                    iris_loc = str(text["iris_loc"][count])
                    eye_loc = str(text["eye_loc"][count])
                    gaze_angle_az = str(text["gaze_angle_az"][count])
                    gaze_angle_el = str(text["gaze_angle_el"][count])
                    ortho_scale = str(text["ortho_scale"][count])
                    cam_az = str(text["cam_az"][count])
                    cam_el = str(text["cam_el"][count])
                    glasses = str(text["glasses"][count])
                    pupil = str(text["pupil"][count])
                    eye_lid = str(text["eye_lid"][count])
                    iris_rot = str(text["iris_rot"][count])
                    left_corner = str(text["left_corner"][count])
                    right_corner = str(text["right_corner"][count])
                    sclera = str(text["sclera"][count])

                    img_dir = img_dir.replace('Z:', 'DataBase').replace('\\','/')
                    label_dir = label_dir.replace('Z:', 'DataBase').replace('\\','/')

                    value = (img_dir, img_format, img_width, img_height, color_space, label_dir, label_format, camera_3d_center, camera_distance, iris_loc, eye_loc, gaze_angle_az, gaze_angle_el, ortho_scale, cam_az, cam_el,
                    glasses, pupil, eye_lid, iris_rot, left_corner, right_corner, sclera)
                    value_list1.append(value)

                    count += 1

            except Exception as ex:
                error_list.append((label, str(ex)))
                print(f"Error loading data from file: {label}")
                print(f"Error details: {ex}")

                # query 실행
            if len(value_list1) >= 300:
                # print(value_list1[0])
                doUT.insert_dataset_values(query2, value_list1)
                value_list1 = []
                print(f'{count} / {len(data_names)}')

        count = 0

doUT.insert_dataset_values(query2, value_list1)
# print(value_list2)
value_list1 = []
print('done')
# Out:
# insert 300 done
# 300 / 24
# insert 300 done
# 600 / 24
# insert 300 done
# 900 / 24
# insert 300 done
# 1200 / 24
# insert 300 done
# 1500 / 24
# insert 300 done
# 1800 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\1\1-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 100 / 24
# insert 300 done
# 400 / 24
# insert 300 done
# 700 / 24
# insert 300 done
# 1000 / 24
# insert 300 done
# 1300 / 24
# insert 300 done
# 1600 / 24
# insert 300 done
# 1900 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\1\1-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 200 / 24
# insert 300 done
# 500 / 24
# insert 300 done
# 800 / 24
# insert 300 done
# 1100 / 24
# insert 300 done
# 1400 / 24
# insert 300 done
# 1700 / 24
# insert 300 done
# 2000 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\1\1-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 300 / 24
# insert 300 done
# 600 / 24
# insert 300 done
# 900 / 24
# insert 300 done
# 1200 / 24
# insert 300 done
# 1500 / 24
# insert 300 done
# 1800 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\1\1-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 100 / 24
# insert 300 done
# 400 / 24
# insert 300 done
# 700 / 24
# insert 300 done
# 1000 / 24
# insert 300 done
# 1300 / 24
# insert 300 done
# 1600 / 24
# insert 300 done
# 1900 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\10\10-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 200 / 24
# insert 300 done
# 500 / 24
# insert 300 done
# 800 / 24
# insert 300 done
# 1100 / 24
# insert 300 done
# 1400 / 24
# insert 300 done
# 1700 / 24
# insert 300 done
# 2000 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\10\10-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 300 / 24
# insert 300 done
# 600 / 24
# insert 300 done
# 900 / 24
# insert 300 done
# 1200 / 24
# insert 300 done
# 1500 / 24
# insert 300 done
# 1800 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\10\10-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 100 / 24
# insert 300 done
# 400 / 24
# insert 300 done
# 700 / 24
# insert 300 done
# 1000 / 24
# insert 300 done
# 1300 / 24
# insert 300 done
# 1600 / 24
# insert 300 done
# 1900 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\10\10-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 200 / 24
# insert 300 done
# 500 / 24
# insert 300 done
# 800 / 24
# insert 300 done
# 1100 / 24
# insert 300 done
# 1400 / 24
# insert 300 done
# 1700 / 24
# insert 300 done
# 2000 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\11\11-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 300 / 24
# insert 300 done
# 600 / 24
# insert 300 done
# 900 / 24
# insert 300 done
# 1200 / 24
# insert 300 done
# 1500 / 24
# insert 300 done
# 1800 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\11\11-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 100 / 24
# insert 300 done
# 400 / 24
# insert 300 done
# 700 / 24
# insert 300 done
# 1000 / 24
# insert 300 done
# 1300 / 24
# insert 300 done
# 1600 / 24
# insert 300 done
# 1900 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\11\11-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 200 / 24
# insert 300 done
# 500 / 24
# insert 300 done
# 800 / 24
# insert 300 done
# 1100 / 24
# insert 300 done
# 1400 / 24
# insert 300 done
# 1700 / 24
# insert 300 done
# 2000 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\11\11-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 300 / 24
# insert 300 done
# 600 / 24
# insert 300 done
# 900 / 24
# insert 300 done
# 1200 / 24
# insert 300 done
# 1500 / 24
# insert 300 done
# 1800 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 100 / 24
# insert 300 done
# 400 / 24
# insert 300 done
# 700 / 24
# insert 300 done
# 1000 / 24
# insert 300 done
# 1300 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 1600 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 1900 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\12\12-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\13\13-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\13\13-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\13\13-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\13\13-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\14\14-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\14\14-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\14\14-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\14\14-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\15\15-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\15\15-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\15\15-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\15\15-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\16\16-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\16\16-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\16\16-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\16\16-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\17\17-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\17\17-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\17\17-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\17\17-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\18\18-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\18\18-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\18\18-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\18\18-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\19\19-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\19\19-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\19\19-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\19\19-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\2\2-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\2\2-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\2\2-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\2\2-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\20\20-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\20\20-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\20\20-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\20\20-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\21\21-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\21\21-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\21\21-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\21\21-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\22\22-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\22\22-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\22\22-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\22\22-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\23\23-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\23\23-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\23\23-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\23\23-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\24\24-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\24\24-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\24\24-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\24\24-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\3\3-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\3\3-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\3\3-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\3\3-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\4\4-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\4\4-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\4\4-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\4\4-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\5\5-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\5\5-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\5\5-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\5\5-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\6\6-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\6\6-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\6\6-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\6\6-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\7\7-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\7\7-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\7\7-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\7\7-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\8\8-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\8\8-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\8\8-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\8\8-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\9\9-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 11 / 24
# insert 300 done
# 311 / 24
# insert 300 done
# 611 / 24
# insert 300 done
# 911 / 24
# insert 300 done
# 1211 / 24
# insert 300 done
# 1511 / 24
# insert 300 done
# 1811 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\9\9-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 111 / 24
# insert 300 done
# 411 / 24
# insert 300 done
# 711 / 24
# insert 300 done
# 1011 / 24
# insert 300 done
# 1311 / 24
# insert 300 done
# 1611 / 24
# insert 300 done
# 1911 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\9\9-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 211 / 24
# insert 300 done
# 511 / 24
# insert 300 done
# 811 / 24
# insert 300 done
# 1111 / 24
# insert 300 done
# 1411 / 24
# insert 300 done
# 1711 / 24
# Error loading data from file: Z:\RIT_Eyes_s_general\data\labeldata\9\9-general.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 289 done
# done

# %% [markdown]
# ## query 작성

# %%
query1 = (f'''CREATE TABLE IF NOT EXISTS RIT_Eyes_s_natural_info (
        id INT(11) NOT NULL AUTO_INCREMENT primary key,
        img_dir VARCHAR(100) NOT NULL,
        img_format VARCHAR(10) NOT NULL,
        img_width INT(11) NOT NULL,
        img_height INT(11) NOT NULL,
        color_space VARCHAR(10) NOT NULL,
        label_dir VARCHAR(100) NOT NULL,
        label_format VARCHAR(10) NOT NULL,
        camera_3d_center VARCHAR(200) NOT NULL,
        camera_distance VARCHAR(200) NOT NULL,
        iris_loc VARCHAR(200) NOT NULL,
        eye_loc VARCHAR(200) NOT NULL,
        gaze_angle_az VARCHAR(200) NOT NULL,
        gaze_angle_el VARCHAR(200) NOT NULL,
        ortho_scale VARCHAR(200) NOT NULL,
        cam_az VARCHAR(200) NOT NULL,
        cam_el VARCHAR(200) NOT NULL,
        glasses VARCHAR(200) NOT NULL,
        pupil VARCHAR(200) NOT NULL,
        eye_lid VARCHAR(200) NOT NULL,
        iris_rot VARCHAR(200) NOT NULL,
        left_corner VARCHAR(200) NOT NULL,
        right_corner VARCHAR(200) NOT NULL,
        sclera VARCHAR(200) NOT NULL)''')

# %%
query2 = (f'''INSERT INTO RIT_Eyes_s_natural_info 
        (img_dir, img_format, img_width, img_height, color_space,
          label_dir, label_format, camera_3d_center, camera_distance,
          iris_loc, eye_loc, gaze_angle_az, gaze_angle_el, ortho_scale, cam_az, cam_el,
          glasses, pupil, eye_lid, iris_rot, left_corner, right_corner, sclera) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''')

# %% [markdown]
# ## query 실행

# %%
try:
    doUT.create_table(query1)
except Exception as e:
    print(f"Error during table creation: {e}")
# Out:
# create table done

# %%
# label 경로
label_path = 'Z:\\RIT_Eyes_s_natural\\data\\labeldata'
image_path = 'Z:\\RIT_Eyes_s_natural\\data\\rawdata'

value_list1 = []
error_list = []
count = 0

data_names = os.listdir(image_path)
for data_name in data_names:
    image_path1 = os.path.join(image_path,data_name) 
    for accesory in os.listdir(image_path1):
        image_path2 = os.path.join(image_path1,accesory)
        for image_name in os.listdir(image_path2):
            image = os.path.join(image_path2,image_name)
            # print(image_path1)
            # print(image_path2)
            # print(image)
            label_path = image_path1.replace("rawdata","labeldata")
            label_name = os.listdir(label_path)
            # print(label_name)
            # Check if the list is empty
            if not label_name:
                print(f"No files found in {label_path}")
                continue  # Skip to the next iteration of the loop

            label = os.path.join(label_path,str(label_name[0]).replace('[','').replace(']','').replace("'",'').replace("'",''))
            try:
                with open(label, 'rb') as f:
                    text = pickle.load(f)
                    img_dir = image
                    img_format = 'tif'
                    image = cv2.imread(img_dir)
                    img_width = image.shape[1]
                    img_height = image.shape[0]
                    color_check = img_dir.split('\\')[-2]
                    if color_check == 'synthetic':
                        color_space = 'IR'
                    else:
                        color_space = 'SEGMENT'
                    label_dir = label
                    label_format = 'p'
                    camera_3d_center = str(text["camera_3d_center"][count])
                    camera_distance = str(text["camera_distance"][count])
                    iris_loc = str(text["iris_loc"][count])
                    eye_loc = str(text["eye_loc"][count])
                    gaze_angle_az = str(text["gaze_angle_az"][count])
                    gaze_angle_el = str(text["gaze_angle_el"][count])
                    ortho_scale = str(text["ortho_scale"][count])
                    cam_az = str(text["cam_az"][count])
                    cam_el = str(text["cam_el"][count])
                    glasses = str(text["glasses"][count])
                    pupil = str(text["pupil"][count])
                    eye_lid = str(text["eye_lid"][count])
                    iris_rot = str(text["iris_rot"][count])
                    left_corner = str(text["left_corner"][count])
                    right_corner = str(text["right_corner"][count])
                    sclera = str(text["sclera"][count])

                    img_dir = img_dir.replace('Z:', 'DataBase')
                    label_dir = label_dir.replace('Z:', 'DataBase')

                    value = (img_dir, img_format, img_width, img_height, color_space, label_dir, label_format, camera_3d_center, camera_distance, iris_loc, eye_loc, gaze_angle_az, gaze_angle_el, ortho_scale, cam_az, cam_el,
                    glasses, pupil, eye_lid, iris_rot, left_corner, right_corner, sclera)
                    value_list1.append(value)

                    count += 1

            except Exception as ex:
                error_list.append((label, str(ex)))
                print(f"Error loading data from file: {label}")
                print(f"Error details: {ex}")

                # query 실행
            if len(value_list1) >= 300:
                # print(value_list1[0])
                doUT.insert_dataset_values(query2, value_list1)
                value_list1 = []
                print(f'{len(data_name)} / {len(data_names)}')

        count = 0

doUT.insert_dataset_values(query2, value_list1)
# print(value_list2)
value_list1 = []
print('done')
# Out:
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_natural\data\labeldata\12\12-natural.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_natural\data\labeldata\12\12-natural.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_natural\data\labeldata\12\12-natural.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_natural\data\labeldata\12\12-natural.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_natural\data\labeldata\12\12-natural.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_natural\data\labeldata\12\12-natural.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_natural\data\labeldata\12\12-natural.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_natural\data\labeldata\12\12-natural.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_natural\data\labeldata\12\12-natural.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_natural\data\labeldata\12\12-natural.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_natural\data\labeldata\12\12-natural.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 289 done
# done

# %% [markdown]
# ## query 작성

# %%
query1 = (f'''CREATE TABLE IF NOT EXISTS RIT_Eyes_s_nvgaze_info (
        id INT(11) NOT NULL AUTO_INCREMENT primary key,
        img_dir VARCHAR(100) NOT NULL,
        img_format VARCHAR(10) NOT NULL,
        img_width INT(11) NOT NULL,
        img_height INT(11) NOT NULL,
        color_space VARCHAR(10) NOT NULL,
        label_dir VARCHAR(100) NOT NULL,
        label_format VARCHAR(10) NOT NULL,
        camera_3d_center VARCHAR(200) NOT NULL,
        camera_distance VARCHAR(200) NOT NULL,
        iris_loc VARCHAR(200) NOT NULL,
        eye_loc VARCHAR(200) NOT NULL,
        gaze_angle_az VARCHAR(200) NOT NULL,
        gaze_angle_el VARCHAR(200) NOT NULL,
        ortho_scale VARCHAR(200) NOT NULL,
        cam_az VARCHAR(200) NOT NULL,
        cam_el VARCHAR(200) NOT NULL,
        glasses VARCHAR(200) NOT NULL,
        pupil VARCHAR(200) NOT NULL,
        eye_lid VARCHAR(200) NOT NULL,
        iris_rot VARCHAR(200) NOT NULL,
        left_corner VARCHAR(200) NOT NULL,
        right_corner VARCHAR(200) NOT NULL,
        sclera VARCHAR(200) NOT NULL)''')

# %%
query2 = (f'''INSERT INTO RIT_Eyes_s_nvgaze_info 
        (img_dir, img_format, img_width, img_height, color_space,
          label_dir, label_format, camera_3d_center, camera_distance,
          iris_loc, eye_loc, gaze_angle_az, gaze_angle_el, ortho_scale, cam_az, cam_el,
          glasses, pupil, eye_lid, iris_rot, left_corner, right_corner, sclera) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''')

# %% [markdown]
# ## query 실행

# %%
try:
    doUT.create_table(query1)
except Exception as e:
    print(f"Error during table creation: {e}")
# Out:
# create table done

# %%
# label 경로
label_path = 'Z:\\RIT_Eyes_s_nvgaze\\data\\labeldata'
image_path = 'Z:\\RIT_Eyes_s_nvgaze\\data\\rawdata'

value_list1 = []
error_list = []
count = 0

data_names = os.listdir(image_path)
for data_name in data_names:
    image_path1 = os.path.join(image_path,data_name) 
    for accesory in os.listdir(image_path1):
        image_path2 = os.path.join(image_path1,accesory)
        for image_name in os.listdir(image_path2):
            image = os.path.join(image_path2,image_name)
            # print(image_path1)
            # print(image_path2)
            # print(image)
            label_path = image_path1.replace("rawdata","labeldata")
            label_name = os.listdir(label_path)
            # print(label_name)
            # Check if the list is empty
            if not label_name:
                print(f"No files found in {label_path}")
                continue  # Skip to the next iteration of the loop

            label = os.path.join(label_path,str(label_name[0]).replace('[','').replace(']','').replace("'",'').replace("'",''))
            try:
                with open(label, 'rb') as f:
                    text = pickle.load(f)
                    img_dir = image
                    img_format = 'tif'
                    image = cv2.imread(img_dir)
                    img_width = image.shape[1]
                    img_height = image.shape[0]
                    color_check = img_dir.split('\\')[-2]
                    if color_check == 'synthetic':
                        color_space = 'IR'
                    else:
                        color_space = 'SEGMENT'
                    label_dir = label
                    label_format = 'p'
                    camera_3d_center = str(text["camera_3d_center"][count])
                    camera_distance = str(text["camera_distance"][count])
                    iris_loc = str(text["iris_loc"][count])
                    eye_loc = str(text["eye_loc"][count])
                    gaze_angle_az = str(text["gaze_angle_az"][count])
                    gaze_angle_el = str(text["gaze_angle_el"][count])
                    ortho_scale = str(text["ortho_scale"][count])
                    cam_az = str(text["cam_az"][count])
                    cam_el = str(text["cam_el"][count])
                    glasses = str(text["glasses"][count])
                    pupil = str(text["pupil"][count])
                    eye_lid = str(text["eye_lid"][count])
                    iris_rot = str(text["iris_rot"][count])
                    left_corner = str(text["left_corner"][count])
                    right_corner = str(text["right_corner"][count])
                    sclera = str(text["sclera"][count])

                    img_dir = img_dir.replace('Z:', 'DataBase')
                    label_dir = label_dir.replace('Z:', 'DataBase')

                    value = (img_dir, img_format, img_width, img_height, color_space, label_dir, label_format, camera_3d_center, camera_distance, iris_loc, eye_loc, gaze_angle_az, gaze_angle_el, ortho_scale, cam_az, cam_el,
                    glasses, pupil, eye_lid, iris_rot, left_corner, right_corner, sclera)
                    value_list1.append(value)

                    count += 1

            except Exception as ex:
                error_list.append((label, str(ex)))
                print(f"Error loading data from file: {label}")
                print(f"Error details: {ex}")

                # query 실행
            if len(value_list1) >= 300:
                print(value_list1[0])
                doUT.insert_dataset_values(query2, value_list1)
                value_list1 = []
                print(f'{len(data_name)} / {len(data_names)}')

        count = 0

doUT.insert_dataset_values(query2, value_list1)
# print(value_list2)
value_list1 = []
print('done')
# Out:
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withoutskin\\0000.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[-0.017064335517883306, -5.02645169052124, -0.08398039662551879]', '3.8038271432595505', '[0.03500239923596382, -1.0023376941680908, 0.010153090581297874]', '[0.0, 0.0, 0.0]', '1.9999997710638548', '0.5799966692718073', '3.8028616905212402', '0', '90', '0', '0.7630667036738225', '0.0', '[-1.5707963705062866, 0.0, 1.046067476272583]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 6.098071575164795]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withoutskin\\0300.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[-0.019101935200691228, -5.635785205688476, -0.4980442079277039]', '4.440256687408862', '[-0.25153762102127075, -0.907015323638916, 0.3464984595775604]', '[0.0, 0.0, 0.0]', '-15.499999292961935', '20.21000132502347', '4.412195205688477', '0', '90', '1', '0.34090549188772873', '0.0', '[-1.5707963705062866, 0.0, 3.6484270095825195]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 5.723413944244385]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withoutskin\\0600.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[0.4995637510490417, -5.308073623504638, 0.27952034747886656]', '4.1244032340078585', '[0.3610363304615021, -0.9212561249732971, 0.16416144371032715]', '[0.0, 0.0, 0.0]', '21.40000036783628', '9.420003153506656', '4.084483623504639', '0', '90', '1', '0.7258969316845159', '0.0', '[-1.5707963705062866, 0.0, 2.232085943222046]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 6.132272243499756]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withoutskin\\0900.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[-0.3193008552718163, -4.915966375198364, -0.23488317453575133]', '3.7135921205727906', '[-0.4247269034385681, -0.8864734172821045, 0.1994514763355255]', '[0.0, 0.0, 0.0]', '-25.599999801693013', '11.470002470615952', '3.6923763751983643', '0', '90', '1', '0.5441703843944786', '0.0', '[-1.5707963705062866, 0.0, 0.1402583122253418]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 4.181136131286621]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withoutskin\\1200.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[-0.46566710131645206, -5.692074878540039, -0.3585802468032837]', '4.506970462781729', '[0.049661457538604736, -0.9803316593170166, -0.2061374932527542]', '[0.0, 0.0, 0.0]', '2.8999999241746837', '-11.859997620801664', '4.468484878540039', '0', '90', '1', '0.755524925220298', '0.0', '[-1.5707963705062866, 0.0, 5.687972545623779]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 3.992981195449829]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withoutskin\\1500.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[0.09885143978118896, -5.502585990753174, 0.10238415724325181]', '4.281362027635944', '[-0.1583142727613449, -0.9883890151977539, -0.06350300461053848]', '[0.0, 0.0, 0.0]', '-9.09999934253868', '-3.6300021615298306', '4.278995990753174', '0', '90', '1', '0.7347273144646543', '0.0', '[-1.5707963705062866, 0.0, 3.9931929111480713]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 2.461099147796631]')
# insert 300 done
# 1 / 23
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: 'NoneType' object has no attribute 'shape'
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withoutskin\\1800.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[-0.20746184687066824, -4.973404510345459, -0.20676271640968322]', '3.7612365122126334', '[-0.2135556936264038, -0.9794548749923706, -0.03272969648241997]', '[0.0, 0.0, 0.0]', '-12.299999317750308', '-1.8699990162009357', '3.749814510345459', '0', '90', '0', '0.7983666269318989', '0.0', '[-1.5707963705062866, 0.0, 2.312007427215576]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 0.9782565236091614]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withskin\\0100.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[-0.2521166156458855, -5.099099262084961, 0.38838314986515043]', '3.903072674123585', '[0.44278091192245483, -0.8880811929702759, 0.14582855999469757]', '[0.0, 0.0, 0.0]', '26.49999846069996', '8.359998775455693', '3.875509262084961', '0', '90', '0', '0.21605406760656026', '0.0', '[-1.5707963705062866, 0.0, 4.435173034667969]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 1.8464045524597168]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withskin\\0400.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[0.1570626769733429, -5.354516609039306, -0.4942038210601807]', '4.163347301212991', '[-0.2395252287387848, -0.9535898566246033, 0.19825035333633423]', '[0.0, 0.0, 0.0]', '-14.100000050858787', '11.39999986181249', '4.130926609039307', '0', '90', '1', '0.5983151894506158', '0.0', '[-1.5707963705062866, 0.0, 4.128183841705322]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 6.214481830596924]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withskin\\0700.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[-0.4533963228988648, -5.0470686987304685, 0.23269182233798505]', '3.857292193942121', '[-0.1795620322227478, -0.9594812989234924, -0.2305694818496704]', '[0.0, 0.0, 0.0]', '-10.60000023805363', '-13.290000176381383', '3.8234786987304688', '0', '90', '0', '0.5803563349355527', '0.0027506351470947266', '[-1.5707963705062866, 0.0, 3.714643716812134]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 2.004973888397217]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withskin\\1000.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[0.4074116323661804, -5.267453296508789, -0.3440107258529663]', '4.078867242083284', '[-0.4028341472148895, -0.9090469479560852, -0.13178543746471405]', '[0.0, 0.0, 0.0]', '-23.89999986822269', '-7.549997990361888', '4.043863296508789', '0', '90', '0', '0.6242639623770857', '0.0', '[-1.5707963705062866, 0.0, 0.19264954328536987]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 5.8897786140441895]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withskin\\1300.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[0.3355647299957275, -4.917579038467407, -0.14995463216018676]', '3.7122291276321784', '[-0.024875331670045853, -0.9499505758285522, 0.3209115266799927]', '[0.0, 0.0, 0.0]', '-1.5000000417413029', '18.6599991759158', '3.6939890384674072', '0', '90', '1', '0.19362915909937928', '0.0', '[-1.5707963705062866, 0.0, 4.526879787445068]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 3.9112162590026855]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\1\\mask-withskin\\1600.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\1\\1-snvgaze.p', 'p', '[-0.044529142551422124, -5.243502242889404, -0.39099462353897096]', '4.039127886153751', '[-0.2706446945667267, -0.9628491997718811, 0.07537822425365448]', '[0.0, 0.0, 0.0]', '-15.699999184690954', '4.309997125961615', '4.019912242889404', '0', '90', '1', '0.19939755154813452', '0.0', '[-1.5707963705062866, 0.0, 4.265537261962891]', '[1.1374797821044922, -0.36298900842666626, -0.11673785746097565]', '[-0.7808918356895447, -0.9031707048416138, -0.17035934329032898]', '[0.0, 0.0, 5.642593860626221]')
# insert 300 done
# 1 / 23
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# Error loading data from file: Z:\RIT_Eyes_s_nvgaze\data\labeldata\1\1-snvgaze.p
# Error details: list index out of range
# ...
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withoutskin\\0000.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.3029893934726715, -5.651012523498535, -0.10364808142185211]', '4.43898813908322', '[-0.16688628494739532, -0.9763249754905701, 0.13761743903160095]', '[0.0, 0.0, 0.0]', '-9.69999987149939', '7.909998592178582', '4.427422523498535', '0', '90', '1', '0.20207613706588745', '0.0', '[-1.5707963705062866, 0.0, 3.3384153842926025]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 2.752676010131836]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withoutskin\\0300.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.37428852915763855, -5.232105357971191, 0.2260078489780426]', '4.032290518545207', '[0.22975999116897583, -0.9644314050674438, -0.13069918751716614]', '[0.0, 0.0, 0.0]', '13.399999576033569', '-7.510000402582293', '4.008515357971191', '0', '90', '1', '0.7971258759498596', '0.16223418712615967', '[-1.5707963705062866, 0.0, 5.0100507736206055]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 6.172098636627197]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withoutskin\\0600.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.21994197368621826, -4.861041410293579, 0.40190446376800537]', '3.666190724994048', '[-0.05981019139289856, -0.9778879880905151, -0.20039398968219757]', '[0.0, 0.0, 0.0]', '-3.500000026248569', '-11.56000205207637', '3.637451410293579', '0', '90', '0', '0.8380708694458008', '0.20836079120635986', '[-1.5707963705062866, 0.0, 2.7964813709259033]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 4.88668966293335]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withoutskin\\0900.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.3958761692047119, -5.497729404296875, -0.16352175176143646]', '4.295547107413277', '[0.3855590224266052, -0.9217085242271423, 0.042398855090141296]', '[0.0, 0.0, 0.0]', '22.70000051784856', '2.430001217293949', '4.274139404296875', '0', '90', '0', '0.17013755440711975', '0.04478883743286133', '[-1.5707963705062866, 0.0, 2.357088088989258]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 4.729109764099121]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withoutskin\\1200.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[0.009348292835056782, -5.219123466339111, 0.1432260423898697]', '3.9981106500987975', '[-0.017407305538654327, -0.9972637891769409, -0.07184556871652603]', '[0.0, 0.0, 0.0]', '-0.9999999922536332', '-4.119999932586538', '3.9955334663391113', '0', '90', '1', '0.4496491849422455', '0.1228562593460083', '[-1.5707963705062866, 0.0, 3.6138176918029785]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 1.5821608304977417]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withoutskin\\1500.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.4428425133228302, -5.448305709686279, -0.2946813702583313]', '4.258071092555108', '[0.14323201775550842, -0.9252225160598755, -0.35135141015052795]', '[0.0, 0.0, 0.0]', '8.800000358718796', '-20.569998284374492', '4.224715709686279', '0', '90', '0', '0.4372618794441223', '0.3073936700820923', '[-1.5707963705062866, 0.0, 1.0402953624725342]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 4.377956867218018]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withoutskin\\1800.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.3403376042842865, -5.480347259368896, 0.21948334574699402]', '4.275977664714826', '[0.2204337865114212, -0.9702429175376892, -0.10018797218799591]', '[0.0, 0.0, 0.0]', '12.799999900846506', '-5.749997257253398', '4.2567572593688965', '0', '90', '0', '0.4132212698459625', '0.14187753200531006', '[-1.5707963705062866, 0.0, 1.4822981357574463]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 6.034699440002441]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withoutskin\\2100.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[0.33468806743621826, -5.015629632797241, -0.10948784649372101]', '3.8083550606159426', '[0.47190314531326294, -0.8800956010818481, 0.052336014807224274]', '[0.47190314531326294, -0.8800956010818481, 0.052336014807224274]', '28.200000101717574', '3.0000009940990253', '3.792039632797241', '0', '90', '0', '0.7225992679595947', '0.9522626996040344', '[-1.5707963705062866, 0.0, 0.8285772800445557]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 3.214639186859131]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withskin\\0200.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[0.15233565866947174, -5.264955623474121, -0.14499184489250183]', '4.046833934149753', '[-0.4158060848712921, -0.8957775235176086, -0.157123863697052]', '[0.0, 0.0, 0.0]', '-24.899999326867793', '-9.039996927611', '4.041365623474121', '0', '90', '1', '0.3829709589481354', '0.17977726459503174', '[-1.5707963705062866, 0.0, 0.18004360795021057]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 3.9553472995758057]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withskin\\0500.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.052681468427181244, -5.395772559967041, -0.15247540175914764]', '4.17530015674926', '[-0.04068944230675697, -0.9708206057548523, -0.2363293170928955]', '[0.0, 0.0, 0.0]', '-2.39999998140872', '-13.669997750855046', '4.172182559967041', '0', '90', '0', '0.35716554522514343', '0.23199617862701416', '[-1.5707963705062866, 0.0, 1.416182518005371]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 1.7910325527191162]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withskin\\0800.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[0.3520675599575043, -5.324573142852783, 0.46482205390930176]', '4.142230540003488', '[-0.07044637948274612, -0.8951061367988586, -0.4402526617050171]', '[0.0, 0.0, 0.0]', '-4.500000125223909', '-26.120005098251752', '4.100983142852783', '0', '90', '1', '0.5161997079849243', '0.36593472957611084', '[-1.5707963705062866, 0.0, 2.1805994510650635]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 0.28192779421806335]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withskin\\1100.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[0.1947845220565796, -5.571210964050293, 0.1265152543783188]', '4.353820755000465', '[0.0092826709151268, -0.8863974809646606, 0.4628320038318634]', '[0.0, 0.0, 0.0]', '0.59999999535218', '27.57000143876494', '4.347620964050293', '0', '90', '0', '0.386342316865921', '0.0', '[-1.5707963705062866, 0.0, 3.639317750930786]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 2.042097330093384]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withskin\\1400.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.45533111691474915, -4.913507802810669, -0.20041754841804504]', '3.7233032392277488', '[-0.26081594824790955, -0.9533826112747192, 0.15177837014198303]', '[0.0, 0.0, 0.0]', '-15.299999401232913', '8.729996952984465', '3.689917802810669', '0', '90', '1', '0.12746083736419678', '0.0', '[-1.5707963705062866, 0.0, 3.011016607284546]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 2.6658756732940674]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withskin\\1700.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.37159597873687744, -5.482805354919433, -0.26643556356430054]', '4.283688471460865', '[-0.385148823261261, -0.8900264501571655, -0.24395346641540527]', '[0.0, 0.0, 0.0]', '-23.39999928512649', '-14.119997934132172', '4.259215354919434', '0', '90', '1', '0.48541563749313354', '0.23700177669525146', '[-1.5707963705062866, 0.0, 1.907879114151001]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 3.2644362449645996]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\mask-withskin\\2000.tif', 'tif', 640, 480, 'SEGMENT', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.42192542552948, -5.259772403564453, 0.17890875041484833]', '4.062117403587267', '[-0.05755399167537689, -0.9981677532196045, -0.018673885613679886]', '[-0.05755399167537689, -0.9981677532196045, -0.018673885613679886]', '-3.299999921076137', '-1.0699994492848504', '4.036182403564453', '0', '90', '1', '0.20207613706588745', '1.0', '[-1.5707963705062866, 0.0, 6.148959159851074]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 2.9676308631896973]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\synthetic\\0100.tif', 'tif', 640, 480, 'IR', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.13772661983966827, -5.346688373413086, -0.03072332963347435]', '4.125512421704467', '[0.37556299567222595, -0.9066891670227051, -0.19200804829597473]', '[0.0, 0.0, 0.0]', '22.50000062611954', '-11.069997450830485', '4.123098373413086', '0', '90', '0', '0.7225992679595947', '0.20283305644989014', '[-1.5707963705062866, 0.0, 4.606187343597412]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 4.789702892303467]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\synthetic\\0400.tif', 'tif', 640, 480, 'IR', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.14002388715744019, -5.0444654062652585, -0.29002293944358826]', '3.8344241894423843', '[0.24244444072246552, -0.9048148989677429, 0.3500438928604126]', '[0.0, 0.0, 0.0]', '15.000000417413029', '20.48999809985898', '3.820875406265259', '0', '90', '0', '0.18751399219036102', '0.0', '[-1.5707963705062866, 0.0, 2.1133100986480713]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 2.0359668731689453]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\synthetic\\0700.tif', 'tif', 640, 480, 'IR', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.15960021317005157, -5.452613456573486, -0.31429415941238403]', '4.243688542168643', '[-0.24987967312335968, -0.9524847269058228, 0.1741638481616974]', '[0.0, 0.0, 0.0]', '-14.699999726045851', '10.030000518091327', '4.229023456573486', '0', '90', '0', '0.45580098032951355', '0.0', '[-1.5707963705062866, 0.0, 2.5704843997955322]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 2.988147735595703]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\synthetic\\1000.tif', 'tif', 640, 480, 'IR', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[-0.13550207018852234, -5.156445129241943, -0.49804189801216125]', '3.9665798883680123', '[0.039829690009355545, -0.9122499227523804, 0.40769314765930176]', '[0.0, 0.0, 0.0]', '2.49999992727323', '24.060001375241242', '3.9328551292419434', '0', '90', '1', '0.20644046366214752', '0.0', '[-1.5707963705062866, 0.0, 1.6958354711532593]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 2.749525308609009]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\synthetic\\1300.tif', 'tif', 640, 480, 'IR', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[0.2766200006008148, -5.161376102294922, -0.3062599301338196]', '3.95935261841693', '[-0.20128512382507324, -0.9551663398742676, 0.2171211987733841]', '[0.0, 0.0, 0.0]', '-11.900000388065912', '12.539999415422628', '3.937786102294922', '0', '90', '1', '0.5669214725494385', '0.0', '[-1.5707963705062866, 0.0, 4.347597599029541]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 1.8751776218414307]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\synthetic\\1600.tif', 'tif', 640, 480, 'IR', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[0.36976438760757446, -5.588290317382812, 0.4354345202445984]', '4.401924327419211', '[-0.005225342698395252, -0.9979578852653503, 0.06366153061389923]', '[0.0, 0.0, 0.0]', '-0.29999999767609', '3.6500027766524568', '4.3647003173828125', '0', '90', '0', '0.450818806886673', '0.02995920181274414', '[-1.5707963705062866, 0.0, 2.676288366317749]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 4.790175914764404]')
# insert 300 done
# 1 / 23
# ('DataBase\\RIT_Eyes_s_nvgaze\\data\\rawdata\\9\\synthetic\\1900.tif', 'tif', 640, 480, 'IR', 'DataBase\\RIT_Eyes_s_nvgaze\\data\\labeldata\\9\\9-snvgaze.p', 'p', '[0.3712732195854187, -5.166492088165283, 0.2566990852355957]', '3.9686540666578973', '[-0.06498666107654572, -0.8849500417709351, 0.4611293077468872]', '[0.0, 0.0, 0.0]', '-4.199999860743554', '27.46000124218189', '3.942902088165283', '0', '90', '1', '0.15343672037124634', '0.0', '[-1.5707963705062866, 0.0, 3.92922043800354]', '[1.1357247829437256, -0.23721864819526672, -0.26803192496299744]', '[-1.0002954006195068, -0.5527873039245605, -0.3560296297073364]', '[0.0, 0.0, 6.045829772949219]')
# insert 300 done
# 1 / 23
# insert 0 done
# done

# %% [markdown]
# ## query 작성

# %%
query1 = (f'''CREATE TABLE IF NOT EXISTS RIT_Eyes_s_openeds_info (
        
        id INT(11) NOT NULL AUTO_INCREMENT primary key,
        img_dir VARCHAR(100) NOT NULL,
        img_format VARCHAR(10) NOT NULL,
        img_width INT(11) NOT NULL,
        img_height INT(11) NOT NULL,
        color_space VARCHAR(10) NOT NULL,
        label_dir VARCHAR(100) NOT NULL,
        label_format VARCHAR(10) NOT NULL,
        camera_3d_center VARCHAR(200) NOT NULL,
        camera_distance VARCHAR(200) NOT NULL,
        iris_loc VARCHAR(200) NOT NULL,
        eye_loc VARCHAR(200) NOT NULL,
        gaze_angle_az VARCHAR(200) NOT NULL,
        gaze_angle_el VARCHAR(200) NOT NULL,
        ortho_scale VARCHAR(200) NOT NULL,
        cam_az VARCHAR(200) NOT NULL,
        cam_el VARCHAR(200) NOT NULL,
        glasses VARCHAR(200) NOT NULL,
        pupil VARCHAR(200) NOT NULL,
        eye_lid VARCHAR(200) NOT NULL,
        iris_rot VARCHAR(200) NOT NULL,
        left_corner VARCHAR(200) NOT NULL,
        right_corner VARCHAR(200) NOT NULL,
        sclera VARCHAR(200) NOT NULL)''')

# %%
query2 = (f'''INSERT INTO RIT_Eyes_s_openeds_info 
        (img_dir, img_format, img_width, img_height, color_space,
          label_dir, label_format, camera_3d_center, camera_distance,
          iris_loc, eye_loc, gaze_angle_az, gaze_angle_el, ortho_scale, cam_az, cam_el,
          glasses, pupil, eye_lid, iris_rot, left_corner, right_corner, sclera) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''')

# %% [markdown]
# ## query 실행

# %%
try:
    doUT.create_table(query1)
except Exception as e:
    print(f"Error during table creation: {e}")
# Out:
# create table done

# %%
# label 경로
label_path = 'Z:\\RIT_Eyes_s_openeds\\data\\labeldata'
image_path = 'Z:\\RIT_Eyes_s_openeds\\data\\rawdata'

value_list1 = []
error_list = []
count = 0

data_names = os.listdir(image_path)
for data_name in data_names:
    image_path1 = os.path.join(image_path,data_name) 
    for accesory in os.listdir(image_path1):
        image_path2 = os.path.join(image_path1,accesory)
        for image_name in os.listdir(image_path2):
            image = os.path.join(image_path2,image_name)
            # print(image_path1)
            # print(image_path2)
            # print(image)
            label_path = image_path1.replace("rawdata","labeldata")
            label_name = os.listdir(label_path)
            # print(label_name)
            # Check if the list is empty
            if not label_name:
                print(f"No files found in {label_path}")
                continue  # Skip to the next iteration of the loop

            label = os.path.join(label_path,str(label_name[0]).replace('[','').replace(']','').replace("'",'').replace("'",''))
            try:
                with open(label, 'rb') as f:
                    text = pickle.load(f)
                    img_dir = image
                    img_format = 'tif'
                    image = cv2.imread(img_dir)
                    img_width = image.shape[1]
                    img_height = image.shape[0]
                    color_check = img_dir.split('\\')[-2]
                    if color_check == 'synthetic':
                        color_space = 'IR'
                    else:
                        color_space = 'SEGMENT'
                    label_dir = label
                    label_format = 'p'
                    camera_3d_center = str(text["camera_3d_center"][count])
                    camera_distance = str(text["camera_distance"][count])
                    iris_loc = str(text["iris_loc"][count])
                    eye_loc = str(text["eye_loc"][count])
                    gaze_angle_az = str(text["gaze_angle_az"][count])
                    gaze_angle_el = str(text["gaze_angle_el"][count])
                    ortho_scale = str(text["ortho_scale"][count])
                    cam_az = str(text["cam_az"][count])
                    cam_el = str(text["cam_el"][count])
                    glasses = str(text["glasses"][count])
                    pupil = str(text["pupil"][count])
                    eye_lid = str(text["eye_lid"][count])
                    iris_rot = str(text["iris_rot"][count])
                    left_corner = str(text["left_corner"][count])
                    right_corner = str(text["right_corner"][count])
                    sclera = str(text["sclera"][count])

                    img_dir = img_dir.replace('Z:', 'DataBase')
                    label_dir = label_dir.replace('Z:', 'DataBase')

                    value = (img_dir, img_format, img_width, img_height, color_space, label_dir, label_format, camera_3d_center, camera_distance, iris_loc, eye_loc, gaze_angle_az, gaze_angle_el, ortho_scale, cam_az, cam_el,
                    glasses, pupil, eye_lid, iris_rot, left_corner, right_corner, sclera)
                    value_list1.append(value)

                    count += 1

            except Exception as ex:
                error_list.append((label, str(ex)))
                print(f"Error loading data from file: {label}")
                print(f"Error details: {ex}")

                # query 실행
            if len(value_list1) >= 300:
                # print(value_list1[0])
                doUT.insert_dataset_values(query2, value_list1)
                value_list1 = []
                print(f'{len(data_name)} / {len(data_names)}')

        count = 0

doUT.insert_dataset_values(query2, value_list1)
# print(value_list2)
value_list1 = []
print('done')
# Out:
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\10\10-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\11\11-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\12\12-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\20\20-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# insert 300 done
# 2 / 24
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# Error loading data from file: Z:\RIT_Eyes_s_openeds\data\labeldata\22\22-sopeneds.p
# Error details: 'NoneType' object has no attribute 'shape'
# ...
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# No files found in Z:\RIT_Eyes_s_openeds\data\labeldata\6
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 300 done
# 1 / 24
# insert 294 done
# done
