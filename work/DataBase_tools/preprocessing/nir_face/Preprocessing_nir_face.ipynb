# %%
import os
import cv2

# %%
def read_pts_file(pts_file_path):
    with open(pts_file_path, 'r') as file:
        lines = file.readlines()
        points = []
        for line in lines:  # Skip the first 3 lines and the last line
            x, y = map(float, line.strip().split())
            points.append((int(x), int(y)))
    return points

# %%
def draw_landmarks(image, points):
    for idx, point in enumerate(points):
        if len(points) < 68:
            print(f"wrong pts {image}")
        cv2.circle(image, point, radius=2, color=(0, 255, 0), thickness=-1)
        # cv2.putText(image, str(idx + 1), (point[0] + 5, point[1] - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1, cv2.LINE_AA)
    return image

# %%
def process_image(label_file_path, img_base_path, output_path):
    # Extracting the image file name from the pts file path
    base_name = os.path.basename(label_file_path).replace('.pts', '.png')
    img_file_path = os.path.join(img_base_path, base_name)
    # print(img_file_path)

    # Read the image
    image = cv2.imread(img_file_path)
    if image is None:
        print(f"Failed to load image: {img_file_path}")
        return

    # Read the points from the pts file
    points = read_pts_file(label_file_path)

    # Draw landmarks on the image
    image_with_landmarks = draw_landmarks(image, points)

    # Save the output image
    output_img_path = os.path.join(output_path, base_name)
    os.makedirs(output_path, exist_ok=True)
    cv2.imwrite(output_img_path, image_with_landmarks)
    print(f"Saved image with landmarks: {output_img_path}")

# %%
if __name__ == "__main__":
    label_path = 'Z:\\nir_face\\data\\IR\\labeldata\\'
    label_ids = os.listdir(label_path)
    for label_id in label_ids:
        label_files = os.listdir(os.path.join(label_path,label_id))
        for label_file in label_files:
            label_dir = os.path.join(label_path,label_id,label_file)
            
            img_path = f'Z:\\nir_face\\data\\IR\\rawdata\\{label_id}'
            output_path = f'Z:\\nir_face\\data\\IR\\lmkdata2\\{label_id}'
            
            process_image(label_dir, img_path, output_path)
# Out:
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-00-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-00-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-01-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-04-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-05-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-06-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-07-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-26-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-29-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-41-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-44-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-46-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-48-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0001\0001-49-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-00-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-05-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-13-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-14-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-16-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-25-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-26-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-29-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-38-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-39-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-46-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-47-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0002\0002-49-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-02-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-09-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-11-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-14-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-15-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-16-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-22-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-27-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-38-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-39-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-41-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-41-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0003\0003-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-25-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-29-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0004\0004-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-01-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-04-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-21-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-26-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-38-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0005\0005-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-04-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-18-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-21-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-26-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-36-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-41-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0006\0006-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-01-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-05-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-25-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-28-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-38-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0007\0007-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-01-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-07-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-11-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-18-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-19-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-36-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0008\0008-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-07-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-11-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-19-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0009\0009-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-00-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-02-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-08-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-11-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-12-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-18-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-21-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-28-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-29-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-33-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-36-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-41-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0010\0010-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-00-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-05-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-21-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-26-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-36-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0011\0011-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-01-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-04-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-05-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-34-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-41-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0012\0012-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-01-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-05-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-09-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-14-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-18-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-18-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-19-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-24-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-27-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-28-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-41-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-41-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-43-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-44-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0013\0013-47-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-01-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-09-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-10-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-19-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-20-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-21-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-24-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-31-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-36-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-38-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-43-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0014\0014-49-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-02-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-04-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-04-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-05-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-07-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-08-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-09-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-13-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-18-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-23-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-28-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-28-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-29-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-32-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-36-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-40-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-41-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0015\0015-48-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-21-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-25-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-28-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-29-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0016\0016-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-01-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-09-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-11-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-15-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-18-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-25-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-27-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-31-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-34-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-38-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-43-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-47-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0017\0017-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-00-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-21-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-25-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-28-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-34-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0018\0018-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-01-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-07-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-19-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-25-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-29-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-36-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-41-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0019\0019-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-01-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-05-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-07-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-11-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-29-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-34-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0020\0020-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-19-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-21-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-29-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-34-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-36-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-38-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0021\0021-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-00-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-05-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-21-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-29-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0022\0022-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-00-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-04-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-13-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-19-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-24-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-25-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-28-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-32-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-38-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-40-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0023\0023-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-03-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-04-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-07-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-10-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-14-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-26-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-27-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-33-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-35-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-39-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-40-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-42-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-44-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0024\0024-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-04-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-05-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-19-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-25-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-28-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-41-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0025\0025-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-04-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-19-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-21-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-25-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-26-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-34-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-36-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-38-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0026\0026-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-01-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-07-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-19-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-26-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0027\0027-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-05-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-21-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-28-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-38-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0028\0028-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-00-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-06-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-16-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-21-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-26-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-33-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-34-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-36-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-36-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-37-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-40-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0029\0029-44-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-00-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-01-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-08-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-15-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-18-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-23-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-24-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-25-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-26-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-29-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-36-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-38-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-44-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-45-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0030\0030-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-03-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-05-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-06-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-08-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-12-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-14-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-16-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-21-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-21-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-22-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-25-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-43-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-48-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0031\0031-49-a-g.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0032\0032-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0032\0032-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0032\0032-04-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0032\0032-05-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0032\0032-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0032\0032-11-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0032\0032-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0032\0032-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0032\0032-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0032\0032-19-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0032\0032-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0032\0032-21-a.png
# ...
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0192\0192-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0192\0192-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0192\0192-28-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0192\0192-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0192\0192-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0192\0192-38-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0192\0192-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0192\0192-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0192\0192-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0192\0192-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-00-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-04-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-11-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-22-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-28-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0193\0193-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-00-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-04-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-21-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-36-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-38-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0194\0194-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-07-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-11-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-29-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-41-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0195\0195-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-00-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-01-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-18-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-19-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-26-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-29-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-36-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-38-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0196\0196-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-01-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-05-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-11-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-25-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-34-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0197\0197-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-07-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-11-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-24-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-26-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-29-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-33-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-39-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0198\0198-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-01-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-11-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-18-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-26-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-28-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-34-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-36-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0199\0199-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-06-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-08-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-11-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-18-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-21-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-25-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-40-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-44-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-47-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0200\0200-48-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-01-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-05-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-10-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-12-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-14-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-20-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-32-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-34-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-37-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-38-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-43-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-45-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0201\0201-46-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-00-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-02-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-03-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-05-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-09-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-11-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-13-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-15-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-16-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-17-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-18-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-23-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-27-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-30-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-31-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-34-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-35-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-36-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-42-a.png
# Saved image with landmarks: Z:\nir_face\data\IR\lmkdata2\0202\0202-47-a.png
