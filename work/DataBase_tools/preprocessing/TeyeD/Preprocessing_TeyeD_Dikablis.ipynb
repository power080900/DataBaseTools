# %% [markdown]
# # mp4 파일 Frame별 이미지 저장

# %%
import cv2
import os
import subprocess

def save_frames_from_video(video_path, output_folder):
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Check if the video file is opened successfully
    if not cap.isOpened():
        print("Error: Could not open video file.")
        return

    # Get the frames per second (fps) of the video
    fps = cap.get(cv2.CAP_PROP_FPS)

    # Get the width and height of the video frames
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    try:
        # Loop through each frame
        frame_count = 0
        while True:
            # Read a frame from the video
            ret, frame = cap.read()

            # If the frame is not read successfully, break the loop
            if not ret:
                break

            # Save the frame as an image using sudo
            frame_count += 1
            frame_filename = f"{output_folder}/frame_{frame_count}.png"
            cv2.imwrite(frame_filename, frame)

            # Break the loop if the 'Esc' key is pressed
            if cv2.waitKey(int(1000 / fps)) & 0xFF == 27:
                break

    finally:
        # Release the video capture object
        cap.release()

# %%
if __name__ == "__main__":
    for j in range(9,33):
        
        video_dir = f"Z:/TEyeD_Dikablis/data/IR/video_resizedata/DikablisT_{j}"
        video_name = os.listdir(video_dir)
        print(video_name)
        for i in video_name:
            print(f'{i} start')
            video_path = f"{video_dir}/{i}"
            video_name = os.path.basename(i).replace('.mp4','')
            output_folder = f"Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_{j}/{video_name}"

            os.makedirs(output_folder, exist_ok=True)

            save_frames_from_video(video_path, output_folder)

            print(f'{output_folder} save done')
# Out:
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '13.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '6.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/12 save done
# 13.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/13 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/5 save done
# 6.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/6 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_9/9 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '13.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '6.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/12 save done
# 13.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/13 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/5 save done
# 6.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/6 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_10/9 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '13.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '6.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/12 save done
# 13.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/13 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/5 save done
# 6.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/6 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_11/9 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '13.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '6.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/12 save done
# 13.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/13 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/5 save done
# 6.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/6 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_12/9 save done
# ['1.mp4', '2.mp4', '3.mp4', '5.mp4', '6.mp4', '7.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_13/1 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_13/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_13/3 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_13/5 save done
# 6.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_13/6 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_13/7 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '13.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_14/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_14/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_14/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_14/12 save done
# 13.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_14/13 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_14/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_14/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_14/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_14/5 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_14/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_14/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_14/9 save done
# ['1.mp4', '2.mp4', '3.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_15/1 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_15/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_15/3 save done
# ['1.mp4', '2.mp4', '3.mp4', '4.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_16/1 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_16/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_16/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_16/4 save done
# ['1.mp4', '2.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_17/1 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_17/2 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '6.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_18/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_18/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_18/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_18/12 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_18/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_18/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_18/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_18/5 save done
# 6.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_18/6 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_18/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_18/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_18/9 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '13.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '6.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/12 save done
# 13.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/13 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/5 save done
# 6.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/6 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_19/9 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '13.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '6.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/12 save done
# 13.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/13 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/5 save done
# 6.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/6 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_20/9 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '6.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_21/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_21/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_21/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_21/12 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_21/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_21/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_21/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_21/5 save done
# 6.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_21/6 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_21/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_21/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_21/9 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_22/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_22/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_22/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_22/12 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_22/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_22/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_22/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_22/5 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_22/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_22/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_22/9 save done
# ['1.mp4', '2.mp4', '3.mp4', '5.mp4', '6.mp4', '7.mp4', '8.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_23/1 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_23/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_23/3 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_23/5 save done
# 6.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_23/6 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_23/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_23/8 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_24/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_24/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_24/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_24/12 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_24/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_24/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_24/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_24/5 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_24/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_24/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_24/9 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '13.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_25/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_25/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_25/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_25/12 save done
# 13.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_25/13 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_25/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_25/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_25/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_25/5 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_25/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_25/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_25/9 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '13.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_26/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_26/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_26/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_26/12 save done
# 13.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_26/13 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_26/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_26/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_26/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_26/5 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_26/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_26/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_26/9 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '13.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '6.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/12 save done
# 13.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/13 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/5 save done
# 6.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/6 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_27/9 save done
# ['1.mp4', '2.mp4', '3.mp4', '4.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_28/1 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_28/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_28/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_28/4 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '13.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_29/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_29/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_29/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_29/12 save done
# 13.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_29/13 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_29/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_29/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_29/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_29/5 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_29/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_29/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_29/9 save done
# ['1.mp4', '2.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_30/1 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_30/2 save done
# ['1.mp4', '10.mp4', '11.mp4', '12.mp4', '13.mp4', '2.mp4', '3.mp4', '4.mp4', '5.mp4', '6.mp4', '7.mp4', '8.mp4', '9.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/1 save done
# 10.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/10 save done
# 11.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/11 save done
# 12.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/12 save done
# 13.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/13 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/2 save done
# 3.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/3 save done
# 4.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/4 save done
# 5.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/5 save done
# 6.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/6 save done
# 7.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/7 save done
# 8.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/8 save done
# 9.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_31/9 save done
# ['1.mp4', '2.mp4']
# 1.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_32/1 save done
# 2.mp4 start
# Z:/TEyeD_Dikablis/data/IR/imgdata/DikablisT_32/2 save done
