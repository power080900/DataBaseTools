# %%
import os
import json
import sys
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
sys.path.append('../../src')
import DISData as DD
import time

# %%
doUT = DD.SQL()
# Out:
# host:  192.168.0.201
# user:  diadmin
# password:  ········
# SQL connection done

# %%
query1_1 = (f'''CREATE TABLE IF NOT EXISTS preventing_drowsy_realroad_box_info(
            id INT PRIMARY KEY AUTO_INCREMENT,
            img_name VARCHAR(255) NOT NULL,
            img_dir VARCHAR(255) NOT NULL,
            img_format VARCHAR(10) NOT NULL,
            img_width INT NOT NULL,
            img_height INT NOT NULL,
            color_space VARCHAR(10) NOT NULL,
            label_name VARCHAR(255) NOT NULL,
            label_dir VARCHAR(1000) NOT NULL,
            label_format VARCHAR(10) NOT NULL,
            occupant_id VARCHAR(10) NOT NULL,
            occupant_sex VARCHAR(20) NOT NULL,
            occupant_age VARCHAR(20) NOT NULL,
            accessory VARCHAR(20),
            box_label VARCHAR(50) NOT NULL,
            box_xtl INT,
            box_ytl INT,
            box_xbr INT,
            box_ybr INT,
            box_rate INT);''')

# %%
query2_1 = (f'''INSERT INTO preventing_drowsy_realroad_box_info 
        (img_name, img_dir, img_format, img_width, img_height, color_space,
        label_name, label_dir, label_format,
        occupant_id, occupant_sex, occupant_age, accessory, box_label, box_xtl, box_ytl, box_xbr, box_ybr, box_rate)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''')

# %%
try:
    doUT.create_table(query1_1)
except Exception as e:
    print(f"Error during table creation: {e}")
# Out:
# create table done

# %%
labels = {1:'M', 2:'F'}

# %%
value_list1 = []

json_dir = "Z:\\preventing_drowsy_realroad\\data\\IR\\labeldata\\"
label_ids = os.listdir(json_dir)
for num, label_id in enumerate(label_ids):
    label_dir = f'{json_dir}\\{label_id}'
    label_lists = os.listdir(label_dir)
    color_space = 'IR'
    for label_file in label_lists:
        label_path = f'{json_dir}\\{label_id}\\{label_file}'
        with open(label_path,'r',encoding='utf-8') as f:
            config = json.load(f)

        img_name = config['FileInfo']['FileName']
        img_dir = '/'.join(os.path.dirname(label_file).replace('label','raw').split('\\')[-6:]+[f'{img_name}'])
        img_format = img_name.split('.')[-1]

        label_dir = '/'.join(os.path.dirname(label_file).split('\\')[-6:]+[os.path.basename(label_file)])
        label_name, label_format = os.path.splitext(os.path.basename(label_file))
        label_format = label_format.replace('.','')

        img_height = config['FileInfo']['Height']
        img_width = config['FileInfo']['Width']
        img_area = int(img_height) * int(img_width)
        # print(config)

        occupant_id = config['UserInfo']['ID']
        occupant_sex = labels[config['UserInfo']['Gender']]
        occupant_age = config['UserInfo']['Age']

        bbox = config['ObjectInfo']['BoundingBox']
        accessories = config['Accessory']

        accessory = []



        for i in accessories:
            if accessories[i] == True:
                accessory.append(i)
        accessory = ",".join(map(str,accessory))

        if accessory == []:
            accessory = 'NULL'

        for box_obj in bbox:
            box = bbox[box_obj]

            if box['isVisible'] == True:
                if not 'Opened' in box:
                    box_label = box_obj
                elif box['Opened'] == True:
                    box_label = f'{box_obj}_Open'
                elif box['Opened'] == False: 
                    box_label = f'{box_obj}_Close'

                box_xtl, box_ytl, box_xbr, box_ybr = box['Position']
                box_area = abs(int(float(box_xtl)) - int(float(box_xbr))) * abs(int(float(box_ytl)) - int(float(box_ybr)))
                f
                box_rate = round((box_area / img_area * 100),2)
                img_dir = img_dir.replace('Z:','DataBase')
                label_dir = label_dir.replace('Z:','DataBase')

                values1 = (img_name, img_dir, img_format, img_width, img_height, color_space,
                          label_name, label_dir, label_format,
                          occupant_id, occupant_sex, occupant_age, accessory, box_label, box_xtl, box_ytl, box_xbr, box_ybr, box_rate)
                # print(values1)
                value_list1.append(values1)

                if len(value_list1) >= 500:
                    doUT.insert_dataset_values(query2_1, value_list1)
                    value_list1 = []
                    print(f'{num} / {len(label_ids)}')

doUT.insert_dataset_values(query2_1, value_list1)
# print(value_list2)
value_list1 = []
print('done')
# Out:
# insert 500 done
# 0 / 594
# insert 500 done
# 0 / 594
# insert 500 done
# 1 / 594
# insert 500 done
# 1 / 594
# insert 500 done
# 2 / 594
# insert 500 done
# 3 / 594
# insert 500 done
# 3 / 594
# insert 500 done
# 4 / 594
# insert 500 done
# 5 / 594
# insert 500 done
# 5 / 594
# insert 500 done
# 6 / 594
# insert 500 done
# 6 / 594
# insert 500 done
# 7 / 594
# insert 500 done
# 7 / 594
# insert 500 done
# 8 / 594
# insert 500 done
# 8 / 594
# insert 500 done
# 9 / 594
# insert 500 done
# 9 / 594
# insert 500 done
# 10 / 594
# insert 500 done
# 10 / 594
# insert 500 done
# 10 / 594
# insert 500 done
# 11 / 594
# insert 500 done
# 12 / 594
# insert 500 done
# 12 / 594
# insert 500 done
# 13 / 594
# insert 500 done
# 13 / 594
# insert 500 done
# 13 / 594
# insert 500 done
# 14 / 594
# insert 500 done
# 14 / 594
# insert 500 done
# 15 / 594
# insert 500 done
# 15 / 594
# insert 500 done
# 16 / 594
# insert 500 done
# 16 / 594
# insert 500 done
# 16 / 594
# insert 500 done
# 17 / 594
# insert 500 done
# 17 / 594
# insert 500 done
# 18 / 594
# insert 500 done
# 18 / 594
# insert 500 done
# 19 / 594
# insert 500 done
# 19 / 594
# insert 500 done
# 20 / 594
# insert 500 done
# 21 / 594
# insert 500 done
# 22 / 594
# insert 500 done
# 22 / 594
# insert 500 done
# 23 / 594
# insert 500 done
# 23 / 594
# insert 500 done
# 24 / 594
# insert 500 done
# 24 / 594
# insert 500 done
# 25 / 594
# insert 500 done
# 25 / 594
# insert 500 done
# 25 / 594
# insert 500 done
# 26 / 594
# insert 500 done
# 26 / 594
# insert 500 done
# 27 / 594
# insert 500 done
# 27 / 594
# insert 500 done
# 28 / 594
# insert 500 done
# 28 / 594
# insert 500 done
# 28 / 594
# insert 500 done
# 29 / 594
# insert 500 done
# 29 / 594
# insert 500 done
# 30 / 594
# insert 500 done
# 30 / 594
# insert 500 done
# 31 / 594
# insert 500 done
# 31 / 594
# insert 500 done
# 31 / 594
# insert 500 done
# 32 / 594
# insert 500 done
# 32 / 594
# insert 500 done
# 33 / 594
# insert 500 done
# 33 / 594
# insert 500 done
# 33 / 594
# insert 500 done
# 34 / 594
# insert 500 done
# 34 / 594
# insert 500 done
# 35 / 594
# insert 500 done
# 35 / 594
# insert 500 done
# 35 / 594
# insert 500 done
# 36 / 594
# insert 500 done
# 36 / 594
# insert 500 done
# 37 / 594
# insert 500 done
# 38 / 594
# insert 500 done
# 39 / 594
# insert 500 done
# 40 / 594
# insert 500 done
# 41 / 594
# insert 500 done
# 41 / 594
# insert 500 done
# 41 / 594
# insert 500 done
# 42 / 594
# insert 500 done
# 42 / 594
# insert 500 done
# 43 / 594
# insert 500 done
# 43 / 594
# insert 500 done
# 43 / 594
# insert 500 done
# 44 / 594
# insert 500 done
# 44 / 594
# insert 500 done
# 44 / 594
# insert 500 done
# 45 / 594
# insert 500 done
# 45 / 594
# insert 500 done
# 46 / 594
# insert 500 done
# 46 / 594
# insert 500 done
# 46 / 594
# insert 500 done
# 47 / 594
# insert 500 done
# 48 / 594
# insert 500 done
# 48 / 594
# insert 500 done
# 48 / 594
# insert 500 done
# 49 / 594
# insert 500 done
# 49 / 594
# insert 500 done
# 50 / 594
# insert 500 done
# 50 / 594
# insert 500 done
# 51 / 594
# insert 500 done
# 52 / 594
# insert 500 done
# 52 / 594
# insert 500 done
# 53 / 594
# insert 500 done
# 53 / 594
# insert 500 done
# 53 / 594
# insert 500 done
# 54 / 594
# insert 500 done
# 55 / 594
# insert 500 done
# 56 / 594
# insert 500 done
# 56 / 594
# insert 500 done
# 57 / 594
# insert 500 done
# 57 / 594
# insert 500 done
# 58 / 594
# insert 500 done
# 58 / 594
# insert 500 done
# 58 / 594
# insert 500 done
# 59 / 594
# insert 500 done
# 59 / 594
# insert 500 done
# 61 / 594
# insert 500 done
# 61 / 594
# insert 500 done
# 61 / 594
# insert 500 done
# 61 / 594
# insert 500 done
# 62 / 594
# insert 500 done
# 62 / 594
# insert 500 done
# 63 / 594
# insert 500 done
# 63 / 594
# insert 500 done
# 64 / 594
# insert 500 done
# 64 / 594
# insert 500 done
# 65 / 594
# insert 500 done
# 65 / 594
# insert 500 done
# 65 / 594
# insert 500 done
# 66 / 594
# insert 500 done
# 66 / 594
# insert 500 done
# 67 / 594
# insert 500 done
# 67 / 594
# insert 500 done
# 68 / 594
# insert 500 done
# 68 / 594
# insert 500 done
# 69 / 594
# insert 500 done
# 69 / 594
# insert 500 done
# 70 / 594
# insert 500 done
# 70 / 594
# insert 500 done
# 70 / 594
# insert 500 done
# 71 / 594
# insert 500 done
# 71 / 594
# insert 500 done
# 72 / 594
# insert 500 done
# 72 / 594
# insert 500 done
# 72 / 594
# insert 500 done
# 72 / 594
# insert 500 done
# 73 / 594
# insert 500 done
# 73 / 594
# insert 500 done
# 74 / 594
# insert 500 done
# 74 / 594
# insert 500 done
# 75 / 594
# insert 500 done
# 75 / 594
# insert 500 done
# 75 / 594
# insert 500 done
# 76 / 594
# insert 500 done
# 76 / 594
# insert 500 done
# 77 / 594
# insert 500 done
# 77 / 594
# insert 500 done
# 77 / 594
# insert 500 done
# 79 / 594
# insert 500 done
# 79 / 594
# insert 500 done
# 79 / 594
# insert 500 done
# 80 / 594
# insert 500 done
# 80 / 594
# insert 500 done
# 81 / 594
# insert 500 done
# 81 / 594
# insert 500 done
# 81 / 594
# insert 500 done
# 82 / 594
# insert 500 done
# 82 / 594
# insert 500 done
# 83 / 594
# insert 500 done
# 83 / 594
# insert 500 done
# 83 / 594
# insert 500 done
# 84 / 594
# insert 500 done
# 84 / 594
# insert 500 done
# 85 / 594
# insert 500 done
# 85 / 594
# insert 500 done
# 86 / 594
# insert 500 done
# 86 / 594
# insert 500 done
# 87 / 594
# insert 500 done
# 87 / 594
# insert 500 done
# 88 / 594
# insert 500 done
# 88 / 594
# insert 500 done
# 89 / 594
# insert 500 done
# 89 / 594
# insert 500 done
# 90 / 594
# insert 500 done
# 90 / 594
# insert 500 done
# 91 / 594
# insert 500 done
# 91 / 594
# insert 500 done
# 91 / 594
# insert 500 done
# 92 / 594
# insert 500 done
# 92 / 594
# insert 500 done
# 93 / 594
# insert 500 done
# 93 / 594
# insert 500 done
# 94 / 594
# insert 500 done
# 94 / 594
# insert 500 done
# 94 / 594
# insert 500 done
# 95 / 594
# insert 500 done
# 95 / 594
# insert 500 done
# 96 / 594
# insert 500 done
# 96 / 594
# insert 500 done
# 96 / 594
# insert 500 done
# 97 / 594
# insert 500 done
# 97 / 594
# insert 500 done
# 98 / 594
# insert 500 done
# 98 / 594
# insert 500 done
# 99 / 594
# insert 500 done
# 99 / 594
# insert 500 done
# 99 / 594
# insert 500 done
# 100 / 594
# insert 500 done
# 101 / 594
# insert 500 done
# 101 / 594
# insert 500 done
# 102 / 594
# insert 500 done
# 102 / 594
# insert 500 done
# 103 / 594
# insert 500 done
# 103 / 594
# insert 500 done
# 103 / 594
# insert 500 done
# 105 / 594
# insert 500 done
# 105 / 594
# insert 500 done
# 105 / 594
# insert 500 done
# 106 / 594
# insert 500 done
# 106 / 594
# insert 500 done
# 107 / 594
# insert 500 done
# 107 / 594
# insert 500 done
# 107 / 594
# insert 500 done
# 108 / 594
# insert 500 done
# 108 / 594
# insert 500 done
# 109 / 594
# insert 500 done
# 109 / 594
# insert 500 done
# 110 / 594
# insert 500 done
# 110 / 594
# insert 500 done
# 111 / 594
# insert 500 done
# 111 / 594
# insert 500 done
# 112 / 594
# insert 500 done
# 113 / 594
# insert 500 done
# 114 / 594
# insert 500 done
# 114 / 594
# insert 500 done
# 115 / 594
# insert 500 done
# 115 / 594
# insert 500 done
# 115 / 594
# insert 500 done
# 117 / 594
# insert 500 done
# 117 / 594
# insert 500 done
# 117 / 594
# insert 500 done
# 118 / 594
# insert 500 done
# 118 / 594
# insert 500 done
# 120 / 594
# insert 500 done
# 120 / 594
# insert 500 done
# 121 / 594
# insert 500 done
# 121 / 594
# insert 500 done
# 122 / 594
# insert 500 done
# 123 / 594
# insert 500 done
# 123 / 594
# insert 500 done
# 123 / 594
# insert 500 done
# 125 / 594
# insert 500 done
# 125 / 594
# insert 500 done
# 125 / 594
# insert 500 done
# 126 / 594
# insert 500 done
# 126 / 594
# insert 500 done
# 127 / 594
# insert 500 done
# 127 / 594
# insert 500 done
# 128 / 594
# insert 500 done
# 128 / 594
# insert 500 done
# 129 / 594
# insert 500 done
# 129 / 594
# insert 500 done
# 130 / 594
# insert 500 done
# 130 / 594
# insert 500 done
# 131 / 594
# insert 500 done
# 131 / 594
# insert 500 done
# 132 / 594
# insert 500 done
# 132 / 594
# insert 500 done
# 133 / 594
# insert 500 done
# 133 / 594
# insert 500 done
# 134 / 594
# insert 500 done
# 134 / 594
# insert 500 done
# 134 / 594
# insert 500 done
# 135 / 594
# insert 500 done
# 136 / 594
# insert 500 done
# 136 / 594
# insert 500 done
# 137 / 594
# insert 500 done
# 137 / 594
# insert 500 done
# 138 / 594
# insert 500 done
# 139 / 594
# insert 500 done
# 139 / 594
# insert 500 done
# 141 / 594
# insert 500 done
# 141 / 594
# insert 500 done
# 142 / 594
# insert 500 done
# 142 / 594
# insert 500 done
# 142 / 594
# insert 500 done
# 143 / 594
# insert 500 done
# 143 / 594
# insert 500 done
# 144 / 594
# insert 500 done
# 145 / 594
# insert 500 done
# 145 / 594
# insert 500 done
# 146 / 594
# insert 500 done
# 147 / 594
# insert 500 done
# 147 / 594
# insert 500 done
# 147 / 594
# insert 500 done
# 148 / 594
# insert 500 done
# 148 / 594
# insert 500 done
# 149 / 594
# insert 500 done
# 150 / 594
# insert 500 done
# 151 / 594
# insert 500 done
# 151 / 594
# insert 500 done
# 151 / 594
# insert 500 done
# 152 / 594
# insert 500 done
# 152 / 594
# insert 500 done
# 153 / 594
# insert 500 done
# 153 / 594
# insert 500 done
# 154 / 594
# insert 500 done
# 154 / 594
# insert 500 done
# 154 / 594
# insert 500 done
# 155 / 594
# insert 500 done
# 155 / 594
# insert 500 done
# 156 / 594
# insert 500 done
# 156 / 594
# insert 500 done
# 157 / 594
# insert 500 done
# 157 / 594
# insert 500 done
# 158 / 594
# insert 500 done
# 158 / 594
# insert 500 done
# 159 / 594
# insert 500 done
# 159 / 594
# insert 500 done
# 159 / 594
# insert 500 done
# 160 / 594
# insert 500 done
# 160 / 594
# insert 500 done
# 161 / 594
# insert 500 done
# 162 / 594
# insert 500 done
# 163 / 594
# insert 500 done
# 163 / 594
# insert 500 done
# 164 / 594
# insert 500 done
# 164 / 594
# insert 500 done
# 165 / 594
# insert 500 done
# 166 / 594
# insert 500 done
# 166 / 594
# insert 500 done
# 166 / 594
# insert 500 done
# 167 / 594
# insert 500 done
# 167 / 594
# insert 500 done
# 168 / 594
# insert 500 done
# 168 / 594
# insert 500 done
# 168 / 594
# insert 500 done
# 169 / 594
# insert 500 done
# 169 / 594
# insert 500 done
# 169 / 594
# insert 500 done
# 170 / 594
# insert 500 done
# 170 / 594
# insert 500 done
# 171 / 594
# insert 500 done
# 171 / 594
# insert 500 done
# 172 / 594
# insert 500 done
# 174 / 594
# insert 500 done
# 174 / 594
# insert 500 done
# 175 / 594
# insert 500 done
# 175 / 594
# insert 500 done
# 177 / 594
# insert 500 done
# 177 / 594
# insert 500 done
# 178 / 594
# insert 500 done
# 178 / 594
# insert 500 done
# 179 / 594
# insert 500 done
# 179 / 594
# insert 500 done
# 179 / 594
# insert 500 done
# 180 / 594
# insert 500 done
# 180 / 594
# insert 500 done
# 181 / 594
# insert 500 done
# 181 / 594
# insert 500 done
# 182 / 594
# insert 500 done
# 182 / 594
# insert 500 done
# 183 / 594
# insert 500 done
# 183 / 594
# insert 500 done
# 183 / 594
# insert 500 done
# 184 / 594
# insert 500 done
# 185 / 594
# insert 500 done
# 186 / 594
# insert 500 done
# 186 / 594
# insert 500 done
# 187 / 594
# insert 500 done
# 187 / 594
# insert 500 done
# 188 / 594
# insert 500 done
# 188 / 594
# insert 500 done
# 188 / 594
# insert 500 done
# 190 / 594
# insert 500 done
# 190 / 594
# insert 500 done
# 191 / 594
# insert 500 done
# 191 / 594
# insert 500 done
# 192 / 594
# insert 500 done
# 192 / 594
# insert 500 done
# 192 / 594
# insert 500 done
# 194 / 594
# insert 500 done
# 194 / 594
# insert 500 done
# 195 / 594
# insert 500 done
# 195 / 594
# insert 500 done
# 195 / 594
# insert 500 done
# 196 / 594
# insert 500 done
# 196 / 594
# insert 500 done
# 197 / 594
# insert 500 done
# 197 / 594
# insert 500 done
# 198 / 594
# insert 500 done
# 198 / 594
# insert 500 done
# 199 / 594
# insert 500 done
# 200 / 594
# insert 500 done
# 201 / 594
# insert 500 done
# 201 / 594
# insert 500 done
# 203 / 594
# insert 500 done
# 204 / 594
# insert 500 done
# 205 / 594
# insert 500 done
# 205 / 594
# insert 500 done
# 206 / 594
# insert 500 done
# 206 / 594
# insert 500 done
# 206 / 594
# insert 500 done
# 208 / 594
# insert 500 done
# 208 / 594
# insert 500 done
# 209 / 594
# insert 500 done
# 209 / 594
# insert 500 done
# 209 / 594
# insert 500 done
# 210 / 594
# insert 500 done
# 210 / 594
# insert 500 done
# 211 / 594
# insert 500 done
# 211 / 594
# insert 500 done
# 211 / 594
# insert 500 done
# 212 / 594
# insert 500 done
# 212 / 594
# insert 500 done
# 213 / 594
# insert 500 done
# 213 / 594
# insert 500 done
# 214 / 594
# insert 500 done
# 214 / 594
# insert 500 done
# 215 / 594
# insert 500 done
# 215 / 594
# insert 500 done
# 216 / 594
# insert 500 done
# 216 / 594
# insert 500 done
# 216 / 594
# insert 500 done
# 217 / 594
# insert 500 done
# 217 / 594
# insert 500 done
# 218 / 594
# insert 500 done
# 218 / 594
# insert 500 done
# 219 / 594
# insert 500 done
# 219 / 594
# insert 500 done
# 219 / 594
# insert 500 done
# 220 / 594
# insert 500 done
# 220 / 594
# insert 500 done
# 221 / 594
# insert 500 done
# 221 / 594
# insert 500 done
# 221 / 594
# insert 500 done
# 221 / 594
# insert 500 done
# 222 / 594
# insert 500 done
# 222 / 594
# insert 500 done
# 223 / 594
# insert 500 done
# 223 / 594
# insert 500 done
# 224 / 594
# insert 500 done
# 224 / 594
# insert 500 done
# 224 / 594
# insert 500 done
# 225 / 594
# insert 500 done
# 226 / 594
# insert 500 done
# 226 / 594
# insert 500 done
# 227 / 594
# insert 500 done
# 227 / 594
# insert 500 done
# 228 / 594
# insert 500 done
# 228 / 594
# insert 500 done
# 229 / 594
# insert 500 done
# 229 / 594
# insert 500 done
# 230 / 594
# insert 500 done
# 230 / 594
# insert 500 done
# 230 / 594
# insert 500 done
# 231 / 594
# insert 500 done
# 231 / 594
# insert 500 done
# 232 / 594
# insert 500 done
# 232 / 594
# insert 500 done
# 234 / 594
# insert 500 done
# 234 / 594
# insert 500 done
# 234 / 594
# insert 500 done
# 235 / 594
# insert 500 done
# 235 / 594
# insert 500 done
# 235 / 594
# insert 500 done
# 236 / 594
# insert 500 done
# 236 / 594
# insert 500 done
# 237 / 594
# insert 500 done
# 237 / 594
# insert 500 done
# 238 / 594
# insert 500 done
# 238 / 594
# insert 500 done
# 239 / 594
# insert 500 done
# 239 / 594
# insert 500 done
# 239 / 594
# insert 500 done
# 240 / 594
# insert 500 done
# 241 / 594
# insert 500 done
# 241 / 594
# insert 500 done
# 241 / 594
# insert 500 done
# 242 / 594
# insert 500 done
# 242 / 594
# insert 500 done
# 242 / 594
# insert 500 done
# 242 / 594
# insert 500 done
# 243 / 594
# insert 500 done
# 243 / 594
# insert 500 done
# 243 / 594
# insert 500 done
# 244 / 594
# insert 500 done
# 244 / 594
# insert 500 done
# 244 / 594
# insert 500 done
# 245 / 594
# insert 500 done
# 245 / 594
# insert 500 done
# 246 / 594
# insert 500 done
# 246 / 594
# insert 500 done
# 246 / 594
# insert 500 done
# 247 / 594
# insert 500 done
# 247 / 594
# insert 500 done
# 247 / 594
# insert 500 done
# 248 / 594
# insert 500 done
# 248 / 594
# insert 500 done
# 248 / 594
# insert 500 done
# 249 / 594
# insert 500 done
# 249 / 594
# insert 500 done
# 249 / 594
# insert 500 done
# 249 / 594
# insert 500 done
# 250 / 594
# insert 500 done
# 250 / 594
# insert 500 done
# 250 / 594
# insert 500 done
# 251 / 594
# insert 500 done
# 251 / 594
# insert 500 done
# 251 / 594
# insert 500 done
# 252 / 594
# insert 500 done
# 252 / 594
# insert 500 done
# 252 / 594
# insert 500 done
# 253 / 594
# insert 500 done
# 253 / 594
# insert 500 done
# 253 / 594
# insert 500 done
# 254 / 594
# insert 500 done
# 254 / 594
# insert 500 done
# 254 / 594
# insert 500 done
# 254 / 594
# insert 500 done
# 255 / 594
# insert 500 done
# 255 / 594
# insert 500 done
# 255 / 594
# insert 500 done
# 256 / 594
# insert 500 done
# 256 / 594
# insert 500 done
# 256 / 594
# insert 500 done
# 257 / 594
# insert 500 done
# 257 / 594
# insert 500 done
# 257 / 594
# insert 500 done
# 258 / 594
# insert 500 done
# 258 / 594
# insert 500 done
# 258 / 594
# insert 500 done
# 259 / 594
# insert 500 done
# 259 / 594
# insert 500 done
# 259 / 594
# insert 500 done
# 259 / 594
# insert 500 done
# 260 / 594
# insert 500 done
# 260 / 594
# insert 500 done
# 260 / 594
# insert 500 done
# 261 / 594
# insert 500 done
# 261 / 594
# insert 500 done
# 261 / 594
# insert 500 done
# 262 / 594
# insert 500 done
# 262 / 594
# insert 500 done
# 262 / 594
# insert 500 done
# 263 / 594
# insert 500 done
# 263 / 594
# insert 500 done
# 263 / 594
# insert 500 done
# 264 / 594
# insert 500 done
# 264 / 594
# insert 500 done
# 264 / 594
# insert 500 done
# 264 / 594
# insert 500 done
# 265 / 594
# insert 500 done
# 265 / 594
# insert 500 done
# 265 / 594
# insert 500 done
# 266 / 594
# insert 500 done
# 266 / 594
# insert 500 done
# 266 / 594
# insert 500 done
# 267 / 594
# insert 500 done
# 267 / 594
# insert 500 done
# 267 / 594
# insert 500 done
# 268 / 594
# insert 500 done
# 268 / 594
# insert 500 done
# 268 / 594
# insert 500 done
# 269 / 594
# insert 500 done
# 269 / 594
# insert 500 done
# 269 / 594
# insert 500 done
# 270 / 594
# insert 500 done
# 270 / 594
# insert 500 done
# 270 / 594
# insert 500 done
# 270 / 594
# insert 500 done
# 271 / 594
# insert 500 done
# 271 / 594
# insert 500 done
# 271 / 594
# insert 500 done
# 272 / 594
# insert 500 done
# 272 / 594
# insert 500 done
# 272 / 594
# insert 500 done
# 273 / 594
# insert 500 done
# 273 / 594
# insert 500 done
# 273 / 594
# insert 500 done
# 274 / 594
# insert 500 done
# 274 / 594
# insert 500 done
# 274 / 594
# insert 500 done
# 275 / 594
# insert 500 done
# 275 / 594
# insert 500 done
# 275 / 594
# insert 500 done
# 275 / 594
# insert 500 done
# 276 / 594
# insert 500 done
# 276 / 594
# insert 500 done
# 276 / 594
# insert 500 done
# 277 / 594
# insert 500 done
# 277 / 594
# insert 500 done
# 278 / 594
# insert 500 done
# 278 / 594
# insert 500 done
# 278 / 594
# insert 500 done
# 279 / 594
# insert 500 done
# 279 / 594
# insert 500 done
# 280 / 594
# insert 500 done
# 280 / 594
# insert 500 done
# 281 / 594
# insert 500 done
# 281 / 594
# insert 500 done
# 282 / 594
# insert 500 done
# 282 / 594
# insert 500 done
# 283 / 594
# insert 500 done
# 283 / 594
# insert 500 done
# 284 / 594
# insert 500 done
# 284 / 594
# insert 500 done
# 284 / 594
# insert 500 done
# 285 / 594
# insert 500 done
# 285 / 594
# insert 500 done
# 285 / 594
# insert 500 done
# 286 / 594
# insert 500 done
# 286 / 594
# insert 500 done
# 287 / 594
# insert 500 done
# 287 / 594
# insert 500 done
# 287 / 594
# insert 500 done
# 288 / 594
# insert 500 done
# 288 / 594
# insert 500 done
# 289 / 594
# insert 500 done
# 289 / 594
# insert 500 done
# 290 / 594
# insert 500 done
# 290 / 594
# insert 500 done
# 290 / 594
# insert 500 done
# 291 / 594
# insert 500 done
# 291 / 594
# insert 500 done
# 292 / 594
# insert 500 done
# 292 / 594
# insert 500 done
# 292 / 594
# insert 500 done
# 293 / 594
# insert 500 done
# 293 / 594
# insert 500 done
# 293 / 594
# insert 500 done
# 294 / 594
# insert 500 done
# 294 / 594
# insert 500 done
# 294 / 594
# insert 500 done
# 295 / 594
# insert 500 done
# 295 / 594
# insert 500 done
# 295 / 594
# insert 500 done
# 296 / 594
# insert 500 done
# 296 / 594
# insert 500 done
# 296 / 594
# insert 500 done
# 297 / 594
# insert 500 done
# 297 / 594
# insert 500 done
# 297 / 594
# insert 500 done
# 298 / 594
# insert 500 done
# 298 / 594
# insert 500 done
# 298 / 594
# insert 500 done
# 299 / 594
# insert 500 done
# 299 / 594
# insert 500 done
# 300 / 594
# insert 500 done
# 300 / 594
# insert 500 done
# 300 / 594
# insert 500 done
# 301 / 594
# insert 500 done
# 301 / 594
# insert 500 done
# 301 / 594
# insert 500 done
# 302 / 594
# insert 500 done
# 302 / 594
# insert 500 done
# 302 / 594
# insert 500 done
# 303 / 594
# insert 500 done
# 303 / 594
# insert 500 done
# 303 / 594
# insert 500 done
# 304 / 594
# insert 500 done
# 304 / 594
# insert 500 done
# 304 / 594
# insert 500 done
# 305 / 594
# insert 500 done
# 305 / 594
# insert 500 done
# 305 / 594
# insert 500 done
# 305 / 594
# insert 500 done
# 306 / 594
# insert 500 done
# 306 / 594
# insert 500 done
# 306 / 594
# insert 500 done
# 307 / 594
# insert 500 done
# 307 / 594
# insert 500 done
# 307 / 594
# insert 500 done
# 308 / 594
# insert 500 done
# 308 / 594
# insert 500 done
# 308 / 594
# insert 500 done
# 309 / 594
# insert 500 done
# 309 / 594
# insert 500 done
# 309 / 594
# insert 500 done
# 310 / 594
# insert 500 done
# 310 / 594
# insert 500 done
# 310 / 594
# insert 500 done
# 311 / 594
# insert 500 done
# 311 / 594
# insert 500 done
# 311 / 594
# insert 500 done
# 312 / 594
# insert 500 done
# 312 / 594
# insert 500 done
# 312 / 594
# insert 500 done
# 312 / 594
# insert 500 done
# 313 / 594
# insert 500 done
# 313 / 594
# insert 500 done
# 313 / 594
# insert 500 done
# 314 / 594
# insert 500 done
# 314 / 594
# insert 500 done
# 314 / 594
# insert 500 done
# 315 / 594
# insert 500 done
# 315 / 594
# insert 500 done
# 316 / 594
# insert 500 done
# 316 / 594
# insert 500 done
# 316 / 594
# insert 500 done
# 316 / 594
# insert 500 done
# 317 / 594
# insert 500 done
# 317 / 594
# insert 500 done
# 317 / 594
# insert 500 done
# 318 / 594
# insert 500 done
# 318 / 594
# insert 500 done
# 318 / 594
# insert 500 done
# 319 / 594
# insert 500 done
# 319 / 594
# insert 500 done
# 319 / 594
# insert 500 done
# 320 / 594
# insert 500 done
# 320 / 594
# insert 500 done
# 320 / 594
# insert 500 done
# 321 / 594
# insert 500 done
# 321 / 594
# insert 500 done
# 321 / 594
# insert 500 done
# 322 / 594
# insert 500 done
# 322 / 594
# insert 500 done
# 322 / 594
# insert 500 done
# 323 / 594
# insert 500 done
# 323 / 594
# insert 500 done
# 323 / 594
# insert 500 done
# 323 / 594
# insert 500 done
# 324 / 594
# insert 500 done
# 324 / 594
# insert 500 done
# 325 / 594
# insert 500 done
# 325 / 594
# insert 500 done
# 326 / 594
# insert 500 done
# 326 / 594
# insert 500 done
# 327 / 594
# insert 500 done
# 327 / 594
# insert 500 done
# 327 / 594
# insert 500 done
# 327 / 594
# insert 500 done
# 328 / 594
# insert 500 done
# 328 / 594
# insert 500 done
# 328 / 594
# insert 500 done
# 329 / 594
# insert 500 done
# 329 / 594
# insert 500 done
# 329 / 594
# insert 500 done
# 330 / 594
# insert 500 done
# 330 / 594
# insert 500 done
# 330 / 594
# insert 500 done
# 331 / 594
# insert 500 done
# 331 / 594
# insert 500 done
# 331 / 594
# insert 500 done
# 331 / 594
# insert 500 done
# 332 / 594
# insert 500 done
# 332 / 594
# insert 500 done
# 332 / 594
# insert 500 done
# 333 / 594
# insert 500 done
# 333 / 594
# insert 500 done
# 333 / 594
# insert 500 done
# 334 / 594
# insert 500 done
# 334 / 594
# insert 500 done
# 334 / 594
# insert 500 done
# 335 / 594
# insert 500 done
# 335 / 594
# insert 500 done
# 335 / 594
# insert 500 done
# 335 / 594
# insert 500 done
# 336 / 594
# insert 500 done
# 336 / 594
# insert 500 done
# 336 / 594
# insert 500 done
# 337 / 594
# insert 500 done
# 337 / 594
# insert 500 done
# 337 / 594
# insert 500 done
# 338 / 594
# insert 500 done
# 338 / 594
# insert 500 done
# 338 / 594
# insert 500 done
# 339 / 594
# insert 500 done
# 339 / 594
# insert 500 done
# 340 / 594
# insert 500 done
# 340 / 594
# insert 500 done
# 341 / 594
# insert 500 done
# 341 / 594
# insert 500 done
# 341 / 594
# insert 500 done
# 342 / 594
# insert 500 done
# 342 / 594
# insert 500 done
# 342 / 594
# insert 500 done
# 343 / 594
# insert 500 done
# 343 / 594
# insert 500 done
# 344 / 594
# insert 500 done
# 344 / 594
# insert 500 done
# 344 / 594
# insert 500 done
# 344 / 594
# insert 500 done
# 345 / 594
# insert 500 done
# 345 / 594
# insert 500 done
# 346 / 594
# insert 500 done
# 346 / 594
# insert 500 done
# 347 / 594
# insert 500 done
# 347 / 594
# insert 500 done
# 347 / 594
# insert 500 done
# 348 / 594
# insert 500 done
# 348 / 594
# insert 500 done
# 348 / 594
# insert 500 done
# 349 / 594
# insert 500 done
# 349 / 594
# insert 500 done
# 349 / 594
# insert 500 done
# 350 / 594
# insert 500 done
# 350 / 594
# insert 500 done
# 351 / 594
# insert 500 done
# 351 / 594
# insert 500 done
# 351 / 594
# insert 500 done
# 351 / 594
# insert 500 done
# 352 / 594
# insert 500 done
# 353 / 594
# insert 500 done
# 353 / 594
# insert 500 done
# 354 / 594
# insert 500 done
# 354 / 594
# insert 500 done
# 354 / 594
# insert 500 done
# 356 / 594
# insert 500 done
# 356 / 594
# insert 500 done
# 356 / 594
# insert 500 done
# 357 / 594
# insert 500 done
# 357 / 594
# insert 500 done
# 357 / 594
# insert 500 done
# 358 / 594
# insert 500 done
# 358 / 594
# insert 500 done
# 359 / 594
# insert 500 done
# 359 / 594
# insert 500 done
# 359 / 594
# insert 500 done
# 359 / 594
# insert 500 done
# 360 / 594
# insert 500 done
# 361 / 594
# insert 500 done
# 361 / 594
# insert 500 done
# 362 / 594
# insert 500 done
# 362 / 594
# insert 500 done
# 362 / 594
# insert 500 done
# 363 / 594
# insert 500 done
# 363 / 594
# insert 500 done
# 363 / 594
# insert 500 done
# 364 / 594
# insert 500 done
# 364 / 594
# insert 500 done
# 364 / 594
# insert 500 done
# 365 / 594
# insert 500 done
# 365 / 594
# insert 500 done
# 365 / 594
# insert 500 done
# 366 / 594
# insert 500 done
# 366 / 594
# insert 500 done
# 366 / 594
# insert 500 done
# 367 / 594
# insert 500 done
# 367 / 594
# insert 500 done
# 367 / 594
# insert 500 done
# 368 / 594
# insert 500 done
# 368 / 594
# insert 500 done
# 368 / 594
# insert 500 done
# 369 / 594
# insert 500 done
# 369 / 594
# insert 500 done
# 369 / 594
# insert 500 done
# 370 / 594
# insert 500 done
# 370 / 594
# insert 500 done
# 370 / 594
# insert 500 done
# 371 / 594
# insert 500 done
# 371 / 594
# insert 500 done
# 371 / 594
# insert 500 done
# 372 / 594
# insert 500 done
# 372 / 594
# insert 500 done
# 372 / 594
# insert 500 done
# 373 / 594
# insert 500 done
# 373 / 594
# insert 500 done
# 373 / 594
# insert 500 done
# 374 / 594
# insert 500 done
# 374 / 594
# insert 500 done
# 374 / 594
# insert 500 done
# 375 / 594
# insert 500 done
# 375 / 594
# insert 500 done
# 375 / 594
# insert 500 done
# 376 / 594
# insert 500 done
# 376 / 594
# insert 500 done
# 376 / 594
# insert 500 done
# 377 / 594
# insert 500 done
# 377 / 594
# insert 500 done
# 378 / 594
# insert 500 done
# 378 / 594
# insert 500 done
# 378 / 594
# insert 500 done
# 379 / 594
# insert 500 done
# 379 / 594
# insert 500 done
# 379 / 594
# insert 500 done
# 380 / 594
# insert 500 done
# 380 / 594
# insert 500 done
# 380 / 594
# insert 500 done
# 381 / 594
# insert 500 done
# 381 / 594
# insert 500 done
# 381 / 594
# insert 500 done
# 381 / 594
# insert 500 done
# 382 / 594
# insert 500 done
# 382 / 594
# insert 500 done
# 382 / 594
# insert 500 done
# 383 / 594
# insert 500 done
# 383 / 594
# insert 500 done
# 383 / 594
# insert 500 done
# 384 / 594
# insert 500 done
# 384 / 594
# insert 500 done
# 384 / 594
# insert 500 done
# 385 / 594
# insert 500 done
# 385 / 594
# insert 500 done
# 385 / 594
# insert 500 done
# 386 / 594
# insert 500 done
# 386 / 594
# insert 500 done
# 386 / 594
# insert 500 done
# 386 / 594
# insert 500 done
# 387 / 594
# insert 500 done
# 387 / 594
# insert 500 done
# 387 / 594
# insert 500 done
# 388 / 594
# insert 500 done
# 388 / 594
# insert 500 done
# 388 / 594
# insert 500 done
# 389 / 594
# insert 500 done
# 389 / 594
# insert 500 done
# 389 / 594
# insert 500 done
# 390 / 594
# insert 500 done
# 390 / 594
# insert 500 done
# 390 / 594
# insert 500 done
# 391 / 594
# insert 500 done
# 391 / 594
# insert 500 done
# 391 / 594
# insert 500 done
# 392 / 594
# insert 500 done
# 392 / 594
# insert 500 done
# 392 / 594
# insert 500 done
# 393 / 594
# insert 500 done
# 393 / 594
# insert 500 done
# 393 / 594
# insert 500 done
# 394 / 594
# insert 500 done
# 394 / 594
# insert 500 done
# 394 / 594
# insert 500 done
# 395 / 594
# insert 500 done
# 395 / 594
# insert 500 done
# 395 / 594
# insert 500 done
# 395 / 594
# insert 500 done
# 396 / 594
# insert 500 done
# 396 / 594
# insert 500 done
# 396 / 594
# insert 500 done
# 397 / 594
# insert 500 done
# 397 / 594
# insert 500 done
# 397 / 594
# insert 500 done
# 398 / 594
# insert 500 done
# 398 / 594
# insert 500 done
# 399 / 594
# insert 500 done
# 399 / 594
# insert 500 done
# 399 / 594
# insert 500 done
# 400 / 594
# insert 500 done
# 400 / 594
# insert 500 done
# 400 / 594
# insert 500 done
# 401 / 594
# insert 500 done
# 401 / 594
# insert 500 done
# 401 / 594
# insert 500 done
# 402 / 594
# insert 500 done
# 402 / 594
# insert 500 done
# 402 / 594
# insert 500 done
# 403 / 594
# insert 500 done
# 403 / 594
# insert 500 done
# 403 / 594
# insert 500 done
# 404 / 594
# insert 500 done
# 404 / 594
# insert 500 done
# 404 / 594
# insert 500 done
# 404 / 594
# insert 500 done
# 405 / 594
# insert 500 done
# 405 / 594
# insert 500 done
# 405 / 594
# insert 500 done
# 406 / 594
# insert 500 done
# 406 / 594
# insert 500 done
# 406 / 594
# insert 500 done
# 407 / 594
# insert 500 done
# 407 / 594
# insert 500 done
# 407 / 594
# insert 500 done
# 408 / 594
# insert 500 done
# 408 / 594
# insert 500 done
# 408 / 594
# insert 500 done
# 409 / 594
# insert 500 done
# 409 / 594
# insert 500 done
# 409 / 594
# insert 500 done
# 410 / 594
# insert 500 done
# 410 / 594
# insert 500 done
# 410 / 594
# insert 500 done
# 411 / 594
# insert 500 done
# 411 / 594
# insert 500 done
# 411 / 594
# insert 500 done
# 412 / 594
# insert 500 done
# 412 / 594
# insert 500 done
# 412 / 594
# insert 500 done
# 413 / 594
# insert 500 done
# 413 / 594
# insert 500 done
# 414 / 594
# insert 500 done
# 414 / 594
# insert 500 done
# 414 / 594
# insert 500 done
# 415 / 594
# insert 500 done
# 415 / 594
# insert 500 done
# 415 / 594
# insert 500 done
# 416 / 594
# insert 500 done
# 416 / 594
# insert 500 done
# 416 / 594
# insert 500 done
# 417 / 594
# insert 500 done
# 417 / 594
# insert 500 done
# 417 / 594
# insert 500 done
# 418 / 594
# insert 500 done
# 418 / 594
# insert 500 done
# 419 / 594
# insert 500 done
# 419 / 594
# insert 500 done
# 419 / 594
# insert 500 done
# 420 / 594
# insert 500 done
# 420 / 594
# insert 500 done
# 420 / 594
# insert 500 done
# 421 / 594
# insert 500 done
# 421 / 594
# insert 500 done
# 421 / 594
# insert 500 done
# 422 / 594
# insert 500 done
# 422 / 594
# insert 500 done
# 422 / 594
# insert 500 done
# 422 / 594
# insert 500 done
# 423 / 594
# insert 500 done
# 423 / 594
# insert 500 done
# 423 / 594
# insert 500 done
# 424 / 594
# insert 500 done
# 424 / 594
# insert 500 done
# 424 / 594
# insert 500 done
# 425 / 594
# insert 500 done
# 425 / 594
# insert 500 done
# 425 / 594
# insert 500 done
# 426 / 594
# insert 500 done
# 426 / 594
# insert 500 done
# 426 / 594
# insert 500 done
# 427 / 594
# insert 500 done
# 427 / 594
# insert 500 done
# 428 / 594
# insert 500 done
# 428 / 594
# insert 500 done
# 429 / 594
# insert 500 done
# 429 / 594
# insert 500 done
# 429 / 594
# insert 500 done
# 430 / 594
# insert 500 done
# 430 / 594
# insert 500 done
# 430 / 594
# insert 500 done
# 430 / 594
# insert 500 done
# 431 / 594
# insert 500 done
# 431 / 594
# insert 500 done
# 432 / 594
# insert 500 done
# 432 / 594
# insert 500 done
# 432 / 594
# insert 500 done
# 433 / 594
# insert 500 done
# 433 / 594
# insert 500 done
# 433 / 594
# insert 500 done
# 434 / 594
# insert 500 done
# 434 / 594
# insert 500 done
# 435 / 594
# insert 500 done
# 435 / 594
# insert 500 done
# 436 / 594
# insert 500 done
# 436 / 594
# insert 500 done
# 436 / 594
# insert 500 done
# 436 / 594
# insert 500 done
# 437 / 594
# insert 500 done
# 437 / 594
# insert 500 done
# 437 / 594
# insert 500 done
# 438 / 594
# insert 500 done
# 439 / 594
# insert 500 done
# 439 / 594
# insert 500 done
# 439 / 594
# insert 500 done
# 440 / 594
# insert 500 done
# 440 / 594
# insert 500 done
# 440 / 594
# insert 500 done
# 441 / 594
# insert 500 done
# 441 / 594
# insert 500 done
# 441 / 594
# insert 500 done
# 442 / 594
# insert 500 done
# 442 / 594
# insert 500 done
# 443 / 594
# insert 500 done
# 443 / 594
# insert 500 done
# 443 / 594
# insert 500 done
# 444 / 594
# insert 500 done
# 444 / 594
# insert 500 done
# 444 / 594
# insert 500 done
# 445 / 594
# insert 500 done
# 445 / 594
# insert 500 done
# 445 / 594
# insert 500 done
# 446 / 594
# insert 500 done
# 446 / 594
# insert 500 done
# 446 / 594
# insert 500 done
# 447 / 594
# insert 500 done
# 447 / 594
# insert 500 done
# 447 / 594
# insert 500 done
# 448 / 594
# insert 500 done
# 448 / 594
# insert 500 done
# 448 / 594
# insert 500 done
# 449 / 594
# insert 500 done
# 449 / 594
# insert 500 done
# 449 / 594
# insert 500 done
# 450 / 594
# insert 500 done
# 450 / 594
# insert 500 done
# 451 / 594
# insert 500 done
# 451 / 594
# insert 500 done
# 451 / 594
# insert 500 done
# 451 / 594
# insert 500 done
# 452 / 594
# insert 500 done
# 452 / 594
# insert 500 done
# 452 / 594
# insert 500 done
# 453 / 594
# insert 500 done
# 454 / 594
# insert 500 done
# 454 / 594
# insert 500 done
# 454 / 594
# insert 500 done
# 455 / 594
# insert 500 done
# 455 / 594
# insert 500 done
# 455 / 594
# insert 500 done
# 456 / 594
# insert 500 done
# 456 / 594
# insert 500 done
# 456 / 594
# insert 500 done
# 457 / 594
# insert 500 done
# 457 / 594
# insert 500 done
# 457 / 594
# insert 500 done
# 458 / 594
# insert 500 done
# 459 / 594
# insert 500 done
# 459 / 594
# insert 500 done
# 459 / 594
# insert 500 done
# 460 / 594
# insert 500 done
# 460 / 594
# insert 500 done
# 460 / 594
# insert 500 done
# 461 / 594
# insert 500 done
# 461 / 594
# insert 500 done
# 461 / 594
# insert 500 done
# 462 / 594
# insert 500 done
# 462 / 594
# insert 500 done
# 462 / 594
# insert 500 done
# 463 / 594
# insert 500 done
# 463 / 594
# insert 500 done
# 463 / 594
# insert 500 done
# 464 / 594
# insert 500 done
# 464 / 594
# insert 500 done
# 464 / 594
# insert 500 done
# 464 / 594
# insert 500 done
# 465 / 594
# insert 500 done
# 465 / 594
# insert 500 done
# 465 / 594
# insert 500 done
# 466 / 594
# insert 500 done
# 466 / 594
# insert 500 done
# 466 / 594
# insert 500 done
# 467 / 594
# insert 500 done
# 467 / 594
# insert 500 done
# 467 / 594
# insert 500 done
# 468 / 594
# insert 500 done
# 468 / 594
# insert 500 done
# 468 / 594
# insert 500 done
# 469 / 594
# insert 500 done
# 469 / 594
# insert 500 done
# 469 / 594
# insert 500 done
# 470 / 594
# insert 500 done
# 470 / 594
# insert 500 done
# 470 / 594
# insert 500 done
# 470 / 594
# insert 500 done
# 471 / 594
# insert 500 done
# 472 / 594
# insert 500 done
# 472 / 594
# insert 500 done
# 472 / 594
# insert 500 done
# 473 / 594
# insert 500 done
# 473 / 594
# insert 500 done
# 473 / 594
# insert 500 done
# 473 / 594
# insert 500 done
# 474 / 594
# insert 500 done
# 474 / 594
# insert 500 done
# 474 / 594
# insert 500 done
# 475 / 594
# insert 500 done
# 475 / 594
# insert 500 done
# 475 / 594
# insert 500 done
# 476 / 594
# insert 500 done
# 476 / 594
# insert 500 done
# 476 / 594
# insert 500 done
# 477 / 594
# insert 500 done
# 477 / 594
# insert 500 done
# 477 / 594
# insert 500 done
# 478 / 594
# insert 500 done
# 478 / 594
# insert 500 done
# 478 / 594
# insert 500 done
# 479 / 594
# insert 500 done
# 479 / 594
# insert 500 done
# 479 / 594
# insert 500 done
# 480 / 594
# insert 500 done
# 480 / 594
# insert 500 done
# 480 / 594
# insert 500 done
# 481 / 594
# insert 500 done
# 481 / 594
# insert 500 done
# 481 / 594
# insert 500 done
# 482 / 594
# insert 500 done
# 482 / 594
# insert 500 done
# 482 / 594
# insert 500 done
# 483 / 594
# insert 500 done
# 483 / 594
# insert 500 done
# 484 / 594
# insert 500 done
# 484 / 594
# insert 500 done
# 484 / 594
# insert 500 done
# 485 / 594
# insert 500 done
# 485 / 594
# insert 500 done
# 485 / 594
# insert 500 done
# 486 / 594
# insert 500 done
# 486 / 594
# insert 500 done
# 486 / 594
# insert 500 done
# 487 / 594
# insert 500 done
# 487 / 594
# insert 500 done
# 487 / 594
# insert 500 done
# 488 / 594
# insert 500 done
# 488 / 594
# insert 500 done
# 488 / 594
# insert 500 done
# 488 / 594
# insert 500 done
# 489 / 594
# insert 500 done
# 489 / 594
# insert 500 done
# 489 / 594
# insert 500 done
# 490 / 594
# insert 500 done
# 490 / 594
# insert 500 done
# 490 / 594
# insert 500 done
# 491 / 594
# insert 500 done
# 491 / 594
# insert 500 done
# 491 / 594
# insert 500 done
# 492 / 594
# insert 500 done
# 492 / 594
# insert 500 done
# 492 / 594
# insert 500 done
# 493 / 594
# insert 500 done
# 493 / 594
# insert 500 done
# 493 / 594
# insert 500 done
# 494 / 594
# insert 500 done
# 494 / 594
# insert 500 done
# 494 / 594
# insert 500 done
# 494 / 594
# insert 500 done
# 495 / 594
# insert 500 done
# 495 / 594
# insert 500 done
# 495 / 594
# insert 500 done
# 496 / 594
# insert 500 done
# 496 / 594
# insert 500 done
# 496 / 594
# insert 500 done
# 497 / 594
# insert 500 done
# 497 / 594
# insert 500 done
# 497 / 594
# insert 500 done
# 498 / 594
# insert 500 done
# 498 / 594
# insert 500 done
# 498 / 594
# insert 500 done
# 499 / 594
# insert 500 done
# 499 / 594
# insert 500 done
# 499 / 594
# insert 500 done
# 499 / 594
# insert 500 done
# 500 / 594
# insert 500 done
# 500 / 594
# insert 500 done
# 500 / 594
# insert 500 done
# 501 / 594
# insert 500 done
# 501 / 594
# insert 500 done
# 501 / 594
# insert 500 done
# 502 / 594
# insert 500 done
# 502 / 594
# insert 500 done
# 502 / 594
# insert 500 done
# 503 / 594
# insert 500 done
# 503 / 594
# insert 500 done
# 503 / 594
# insert 500 done
# 504 / 594
# insert 500 done
# 504 / 594
# insert 500 done
# 504 / 594
# insert 500 done
# 505 / 594
# insert 500 done
# 505 / 594
# insert 500 done
# 505 / 594
# insert 500 done
# 506 / 594
# insert 500 done
# 506 / 594
# insert 500 done
# 506 / 594
# insert 500 done
# 506 / 594
# insert 500 done
# 507 / 594
# insert 500 done
# 507 / 594
# insert 500 done
# 507 / 594
# insert 500 done
# 508 / 594
# insert 500 done
# 509 / 594
# insert 500 done
# 509 / 594
# insert 500 done
# 509 / 594
# insert 500 done
# 510 / 594
# insert 500 done
# 510 / 594
# insert 500 done
# 510 / 594
# insert 500 done
# 510 / 594
# insert 500 done
# 511 / 594
# insert 500 done
# 512 / 594
# insert 500 done
# 512 / 594
# insert 500 done
# 512 / 594
# insert 500 done
# 513 / 594
# insert 500 done
# 513 / 594
# insert 500 done
# 513 / 594
# insert 500 done
# 514 / 594
# insert 500 done
# 514 / 594
# insert 500 done
# 514 / 594
# insert 500 done
# 515 / 594
# insert 500 done
# 515 / 594
# insert 500 done
# 515 / 594
# insert 500 done
# 516 / 594
# insert 500 done
# 516 / 594
# insert 500 done
# 516 / 594
# insert 500 done
# 517 / 594
# insert 500 done
# 517 / 594
# insert 500 done
# 517 / 594
# insert 500 done
# 518 / 594
# insert 500 done
# 518 / 594
# insert 500 done
# 518 / 594
# insert 500 done
# 519 / 594
# insert 500 done
# 519 / 594
# insert 500 done
# 519 / 594
# insert 500 done
# 520 / 594
# insert 500 done
# 520 / 594
# insert 500 done
# 520 / 594
# insert 500 done
# 520 / 594
# insert 500 done
# 521 / 594
# insert 500 done
# 521 / 594
# insert 500 done
# 521 / 594
# insert 500 done
# 522 / 594
# insert 500 done
# 522 / 594
# insert 500 done
# 522 / 594
# insert 500 done
# 523 / 594
# insert 500 done
# 523 / 594
# insert 500 done
# 523 / 594
# insert 500 done
# 524 / 594
# insert 500 done
# 524 / 594
# insert 500 done
# 524 / 594
# insert 500 done
# 525 / 594
# insert 500 done
# 525 / 594
# insert 500 done
# 525 / 594
# insert 500 done
# 526 / 594
# insert 500 done
# 526 / 594
# insert 500 done
# 526 / 594
# insert 500 done
# 527 / 594
# insert 500 done
# 527 / 594
# insert 500 done
# 528 / 594
# insert 500 done
# 528 / 594
# insert 500 done
# 528 / 594
# insert 500 done
# 529 / 594
# insert 500 done
# 529 / 594
# insert 500 done
# 529 / 594
# insert 500 done
# 530 / 594
# insert 500 done
# 531 / 594
# insert 500 done
# 531 / 594
# insert 500 done
# 531 / 594
# insert 500 done
# 531 / 594
# insert 500 done
# 532 / 594
# insert 500 done
# 533 / 594
# insert 500 done
# 533 / 594
# insert 500 done
# 533 / 594
# insert 500 done
# 534 / 594
# insert 500 done
# 534 / 594
# insert 500 done
# 534 / 594
# insert 500 done
# 534 / 594
# insert 500 done
# 535 / 594
# insert 500 done
# 535 / 594
# insert 500 done
# 535 / 594
# insert 500 done
# 536 / 594
# insert 500 done
# 537 / 594
# insert 500 done
# 537 / 594
# insert 500 done
# 537 / 594
# insert 500 done
# 538 / 594
# insert 500 done
# 538 / 594
# insert 500 done
# 538 / 594
# insert 500 done
# 539 / 594
# insert 500 done
# 539 / 594
# insert 500 done
# 539 / 594
# insert 500 done
# 539 / 594
# insert 500 done
# 540 / 594
# insert 500 done
# 540 / 594
# insert 500 done
# 540 / 594
# insert 500 done
# 541 / 594
# insert 500 done
# 541 / 594
# insert 500 done
# 541 / 594
# insert 500 done
# 542 / 594
# insert 500 done
# 542 / 594
# insert 500 done
# 542 / 594
# insert 500 done
# 543 / 594
# insert 500 done
# 543 / 594
# insert 500 done
# 543 / 594
# insert 500 done
# 544 / 594
# insert 500 done
# 544 / 594
# insert 500 done
# 544 / 594
# insert 500 done
# 545 / 594
# insert 500 done
# 545 / 594
# insert 500 done
# 545 / 594
# insert 500 done
# 545 / 594
# insert 500 done
# 546 / 594
# insert 500 done
# 546 / 594
# insert 500 done
# 546 / 594
# insert 500 done
# 547 / 594
# insert 500 done
# 547 / 594
# insert 500 done
# 547 / 594
# insert 500 done
# 548 / 594
# insert 500 done
# 548 / 594
# insert 500 done
# 548 / 594
# insert 500 done
# 549 / 594
# insert 500 done
# 549 / 594
# insert 500 done
# 549 / 594
# insert 500 done
# 550 / 594
# insert 500 done
# 550 / 594
# insert 500 done
# 550 / 594
# insert 500 done
# 551 / 594
# insert 500 done
# 551 / 594
# insert 500 done
# 551 / 594
# insert 500 done
# 552 / 594
# insert 500 done
# 552 / 594
# insert 500 done
# 552 / 594
# insert 500 done
# 552 / 594
# insert 500 done
# 553 / 594
# insert 500 done
# 553 / 594
# insert 500 done
# 553 / 594
# insert 500 done
# 554 / 594
# insert 500 done
# 554 / 594
# insert 500 done
# 554 / 594
# insert 500 done
# 555 / 594
# insert 500 done
# 555 / 594
# insert 500 done
# 555 / 594
# insert 500 done
# 556 / 594
# insert 500 done
# 556 / 594
# insert 500 done
# 556 / 594
# insert 500 done
# 557 / 594
# insert 500 done
# 557 / 594
# insert 500 done
# 557 / 594
# insert 500 done
# 557 / 594
# insert 500 done
# 558 / 594
# insert 500 done
# 558 / 594
# insert 500 done
# 558 / 594
# insert 500 done
# 559 / 594
# insert 500 done
# 559 / 594
# insert 500 done
# 559 / 594
# insert 500 done
# 560 / 594
# insert 500 done
# 560 / 594
# insert 500 done
# 560 / 594
# insert 500 done
# 561 / 594
# insert 500 done
# 561 / 594
# insert 500 done
# 561 / 594
# insert 500 done
# 562 / 594
# insert 500 done
# 562 / 594
# insert 500 done
# 562 / 594
# insert 500 done
# 562 / 594
# insert 500 done
# 563 / 594
# insert 500 done
# 563 / 594
# insert 500 done
# 563 / 594
# insert 500 done
# 564 / 594
# insert 500 done
# 564 / 594
# insert 500 done
# 564 / 594
# insert 500 done
# 565 / 594
# insert 500 done
# 565 / 594
# insert 500 done
# 565 / 594
# insert 500 done
# 566 / 594
# insert 500 done
# 566 / 594
# insert 500 done
# 566 / 594
# insert 500 done
# 567 / 594
# insert 500 done
# 567 / 594
# insert 500 done
# 567 / 594
# insert 500 done
# 567 / 594
# insert 500 done
# 568 / 594
# insert 500 done
# 568 / 594
# insert 500 done
# 568 / 594
# insert 500 done
# 569 / 594
# insert 500 done
# 569 / 594
# insert 500 done
# 569 / 594
# insert 500 done
# 570 / 594
# insert 500 done
# 570 / 594
# insert 500 done
# 570 / 594
# insert 500 done
# 571 / 594
# insert 500 done
# 571 / 594
# insert 500 done
# 571 / 594
# insert 500 done
# 572 / 594
# insert 500 done
# 572 / 594
# insert 500 done
# 572 / 594
# insert 500 done
# 573 / 594
# insert 500 done
# 573 / 594
# insert 500 done
# 573 / 594
# insert 500 done
# 574 / 594
# insert 500 done
# 574 / 594
# insert 500 done
# 574 / 594
# insert 500 done
# 575 / 594
# insert 500 done
# 575 / 594
# insert 500 done
# 575 / 594
# insert 500 done
# 576 / 594
# insert 500 done
# 576 / 594
# insert 500 done
# 576 / 594
# insert 500 done
# 576 / 594
# insert 500 done
# 577 / 594
# insert 500 done
# 577 / 594
# insert 500 done
# 577 / 594
# insert 500 done
# 578 / 594
# insert 500 done
# 579 / 594
# insert 500 done
# 579 / 594
# insert 500 done
# 579 / 594
# insert 500 done
# 580 / 594
# insert 500 done
# 580 / 594
# insert 500 done
# 580 / 594
# insert 500 done
# 581 / 594
# insert 500 done
# 581 / 594
# insert 500 done
# 581 / 594
# insert 500 done
# 582 / 594
# insert 500 done
# 582 / 594
# insert 500 done
# 582 / 594
# insert 500 done
# 583 / 594
# insert 500 done
# 583 / 594
# insert 500 done
# 583 / 594
# insert 500 done
# 583 / 594
# insert 500 done
# 584 / 594
# insert 500 done
# 584 / 594
# insert 500 done
# 584 / 594
# insert 500 done
# 585 / 594
# insert 500 done
# 585 / 594
# insert 500 done
# 585 / 594
# insert 500 done
# 586 / 594
# insert 500 done
# 586 / 594
# insert 500 done
# 586 / 594
# insert 500 done
# 587 / 594
# insert 500 done
# 587 / 594
# insert 500 done
# 587 / 594
# insert 500 done
# 588 / 594
# insert 500 done
# 588 / 594
# insert 500 done
# 588 / 594
# insert 500 done
# 589 / 594
# insert 500 done
# 589 / 594
# insert 500 done
# 589 / 594
# insert 500 done
# 589 / 594
# insert 500 done
# 590 / 594
# insert 500 done
# 590 / 594
# insert 500 done
# 590 / 594
# insert 500 done
# 591 / 594
# insert 500 done
# 591 / 594
# insert 500 done
# 592 / 594
# insert 500 done
# 592 / 594
# insert 500 done
# 592 / 594
# insert 500 done
# 593 / 594
# insert 500 done
# 593 / 594
# insert 434 done
# done
