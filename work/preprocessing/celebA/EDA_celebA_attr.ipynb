# %%
import cv2
import numpy as np
import os
import sys
sys.path.append('../../src')
import DISData as DD
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
doUT = DD.SQL()
# Out:
# host:  192.168.0.128
# user:  diadmin
# password:  ········
# SQL connection done

# %%
data_name = 'celebA_attrib'

# %%
query = f'''select label, count(img_dir) as count from DeepInSight.{data_name}_info group by label;'''

# %%
db = doUT.db
conn = doUT.conn
conn.execute(query)
column_names = [desc[0] for desc in conn.description]
result = conn.fetchall()
db.commit()

# %%
df = pd.DataFrame(result, columns=column_names)
df['count'] = df['count'].astype('int64')

# %%
df = df.sort_values(by='count',ascending=False)
df
# Out:
#              label   count
# 3  Facial_Features  453201
# 5       hair_style  270748
# 4      facial_hair  224256
# 0        accessory  196647
# 6            style  182223
# 2        face_type  161415
# 1              etc   10312

# %%
try:
    plt.figure(figsize=(8, 6))
    sns.set(style="whitegrid")
    ax = sns.barplot(x='label', y='count', data=df, hue='label')
    for p in ax.patches:
        label = p.get_height()  # 막대의 너비를 가져와서 count로 사용
        count = p.get_x() + p.get_width() / 2  # 막대의 y 좌표를 가져와서 label로 사용
        ax.annotate(f'{label}', (count, label), ha='center', va='center', fontsize=10, color='black')
    plt.xlabel('label')
    plt.ylabel('count')
    plt.title('Count of Labels')
    save_path = f'label/{data_name}_label.png'
    if not os.path.exists('label'):
        os.makedirs('label')
    if os.path.exists(save_path):
        os.remove(save_path)
    plt.savefig(save_path)
except Exception as e:
    print(e)

# %%
query2 = f'''select label, value, count(img_dir) as count from DeepInSight.{data_name}_info group by label, value;'''

# %%
db = doUT.db
conn = doUT.conn
conn.execute(query2)
column_names = [desc[0] for desc in conn.description]
result2 = conn.fetchall()
db.commit()

# %%
df2 = pd.DataFrame(result2, columns=column_names)
df2['count'] = df2['count'].astype('int64')

# %%
df2 = df2.sort_values(by='label',ascending=True)
df2
# Out:
#               label                value   count
# 17  Facial_Features      High_Cheekbones   92189
# 20  Facial_Features              Smiling   97669
# 19  Facial_Features          Narrow_Eyes   23329
# 18  Facial_Features  Mouth_Slightly_Open   97942
# 16  Facial_Features               Chubby   11663
# 15  Facial_Features       Bushy_Eyebrows   28803
# 14  Facial_Features             Big_Nose   47516
# 13  Facial_Features      Arched_Eyebrows   54090
# 0         accessory           Eyeglasses   13193
# 5         accessory      Wearing_Necktie   14732
# 4         accessory     Wearing_Necklace   24913
# 3         accessory     Wearing_Lipstick   95715
# 2         accessory          Wearing_Hat    9818
# 1         accessory     Wearing_Earrings   38276
# 6               etc               Blurry   10312
# 9         face_type            Pale_Skin    8701
# 10        face_type          Pointy_Nose   56210
# 11        face_type    Receding_Hairline   16163
# 12        face_type          Rosy_Cheeks   13315
# 7         face_type          Double_Chin    9459
# 8         face_type            Oval_Face   57567
# 25      facial_hair            Sideburns   11449
# 24      facial_hair  Shadow_of_5_o_clock   22516
# 22      facial_hair             Mustache    8417
# 21      facial_hair               Goatee   12716
# 23      facial_hair             No_Beard  169158
# 26       hair_style                 Bald    4547
# 27       hair_style                Bangs   30709
# 28       hair_style           Black_Hair   48472
# 29       hair_style           Blond_Hair   29983
# 30       hair_style           Brown_Hair   41572
# 31       hair_style            Gray_Hair    8499
# 32       hair_style        Straight_Hair   42222
# 33       hair_style            Wavy_Hair   64744
# 34            style           Attractive  103833
# 35            style         Heavy_Makeup   78390

# %%
try:
    plt.figure(figsize=(8, 12))
    sns.set(style="whitegrid")
    ax = sns.barplot(x='value', y='count', data=df2, hue='label')
    plt.xticks(rotation=45, ha='right')  # x 축 라벨들을 45도 기울임
    for p in ax.patches:
        label = p.get_height()  # 막대의 너비를 가져와서 count로 사용
        count = p.get_x() + p.get_width() / 2  # 막대의 y 좌표를 가져와서 label로 사용
        ax.annotate(f'{label}', (count, label), ha='center', va='center', fontsize=10, color='black')
    plt.xlabel('label')
    plt.ylabel('count')
    plt.title('Count of Labels')
    save_path = f'label/{data_name}_label2.png'
    if not os.path.exists('label'):
        os.makedirs('label')
    if os.path.exists(save_path):
        os.remove(save_path)
    plt.savefig(save_path)
except Exception as e:
    print(e)
