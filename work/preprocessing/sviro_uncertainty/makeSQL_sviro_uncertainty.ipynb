# %% [markdown]
# # SQL 작성

# %%
import sys
import os
import pandas as pd
from scipy import io
import cv2
from glob import glob
sys.path.append('../../src')
import DISData as DD
import json
import csv

# %% [markdown]
# ## SQL 연결

# %%
doUT = DD.SQL()
# Out:
# host:  192.168.0.201
# user:  diadmin
# password:  ········
# SQL connection done

# %% [markdown]
# # query 작성

# %%
query1 = (f'''CREATE TABLE IF NOT EXISTS sviro_uncertainty_box_info(
            id INT PRIMARY KEY AUTO_INCREMENT,
            img_name VARCHAR(255) NOT NULL,
            img_dir VARCHAR(255) NOT NULL,
            img_format VARCHAR(10) NOT NULL,
            img_width INT NOT NULL,
            img_height INT NOT NULL,
            color_space VARCHAR(10) NOT NULL,
            label_name VARCHAR(255) NOT NULL,
            label_dir VARCHAR(255) NOT NULL,
            label_format VARCHAR(10) NOT NULL,
            location VARCHAR(20) NOT NULL,
            label VARCHAR(100) NOT NULL,
            label_id VARCHAR(100) NOT NULL,
            box_xtl INT,
            box_ytl INT,
            box_xbr INT,
            box_ybr INT);''')

# %%
query2 = (f'''CREATE TABLE IF NOT EXISTS sviro_uncertainty_landmark_info(
            id INT PRIMARY KEY AUTO_INCREMENT,
            img_name VARCHAR(255) NOT NULL,
            img_dir VARCHAR(255) NOT NULL,
            img_format VARCHAR(10) NOT NULL,
            img_width INT NOT NULL,
            img_height INT NOT NULL,
            color_space VARCHAR(10) NOT NULL,
            label_name VARCHAR(255) NOT NULL,
            label_dir VARCHAR(255) NOT NULL,
            label_format VARCHAR(10) NOT NULL,
            location VARCHAR(20) NOT NULL,
            label VARCHAR(100) NOT NULL,
            label_id VARCHAR(100) NOT NULL,
            landmark VARCHAR(1000));''')

# %%
query1_1 = (f'''INSERT INTO sviro_uncertainty_box_info 
        (img_name, img_dir, img_format, img_width, img_height, color_space,
        label_name, label_dir, label_format,
        location, label, label_id, box_xtl, box_ytl, box_xbr, box_ybr)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''')
query2_1 = (f'''INSERT INTO sviro_uncertainty_landmark_info 
        (img_name, img_dir, img_format, img_width, img_height, color_space,
        label_name, label_dir, label_format,
        location, label, label_id, landmark)
        VALUES (%s, %s, %s, %s, %s,  %s, %s, %s, %s, %s,  %s, %s, %s)''')

# %%
labels = {0:'empty', 1:'baby', 2:'child', 3:'adult', 4:'stuff', 5:'babyseat', 6:'childseat'}

# %%
def compress_segmap(arr, n_object=3):
    return arr[:,:,0] + n_object*arr[:,:,1] + n_object*n_object*arr[:,:,2]

# %%
try:
    doUT.create_table(query1)
except Exception as e:
    print(f"Error during table creation: {e}")
# Out:
# Error during table creation: 1050: Table 'sviro_uncertainty_box_info' already exists

# %%
try:
    doUT.create_table(query2)
except Exception as e:
    print(f"Error during table creation: {e}")
# Out:
# Error during table creation: 1050: Table 'sviro_uncertainty_landmark_info' already exists

# %%
import numpy as np

# %%
value_list1 = []
project_id = None
rm_list = []
colors = ['RGB','IR']

for color_space in colors:
    label_path = f'Z:\\sviro_uncertainty\\data\\{color_space}\\labeldata'
    img_path = f'Z:\\sviro_uncertainty\\data\\{color_space}\\rawdata'
    img_ids = os.listdir(img_path)
    for img_id in img_ids:
        img_files = os.listdir(os.path.join(img_path,img_id))  
        for cnt, img_file in enumerate(img_files):
            img = os.path.join(img_path,img_id,img_file)
            img_name, img_format = os.path.splitext(os.path.basename(img))
            img_format = img_format.replace('.','')
            img_dir = img
    
            if color_space != 'SEGMENTATION':
                label_file = img.replace('SEGMENTATION','IR').replace('raw','label').replace('.png','.csv')
                label_dir = '/'.join(os.path.dirname(label_file).split('\\')[-6:]+[os.path.basename(label_file)])
                label_name, label_format = os.path.splitext(os.path.basename(label_file))
                label_format = label_format.replace('.','')

                img_file = os.path.basename(img)
                img_name, img_format = os.path.splitext(img_file)
                img_format = img_format.replace('.','')
                
                # print(img)
                seg_dir = img.replace(f'{color_space}','SEGMENTATION')
                
                try:
                    image = cv2.imread(img)
                
                    img_width = image.shape[1]
                    img_height = image.shape[0]
            
                    seg_img = cv2.imread(seg_dir)
                except:
                    print(f"seg_error : {img}")
                    continue

                arr = np.array(seg_img)

                digitized = np.digitize(arr, bins=[-1,190,256])
                seg_name, seg_format = os.path.splitext(os.path.basename(seg_dir))
                seg_obj = list(map(int,seg_name.split('_')[-3:]))
                i = len(seg_obj) - seg_obj.count(0)
                segmap = compress_segmap(digitized, n_object=i)

                ny, nx = segmap.shape
                unique_keys = np.unique(segmap)

                centers = []
                bboxs = []

                for unik in unique_keys:
                    tmp = np.zeros_like(segmap)
                    tmp[np.where(segmap == unik)] = unik

                    xsum = np.sum(tmp, axis=0)
                    ysum = np.sum(tmp, axis=1)

                    ytl = np.argmax(ysum > 0)
                    ybr = len(ysum) - np.argmax(ysum[::-1] > 0)
                    # print(ytl, ybr)

                    xtl = np.argmax(xsum > 0)
                    xbr = len(xsum) - np.argmax(xsum[::-1] > 0)
                    # print(xtl, xbr)
                    if xtl == 0 and xbr == nx:
                        continue

                    xcen = 0.5 * (xtl + xbr)
                    centers.append(xcen)

                    bboxs.append([xtl, ytl, xbr, ybr])
                    # print(bboxs)

                # x 좌표 기준으로 정렬
                ind_sort = np.argsort(centers)
                # print(bboxs)
                bboxs = np.array(bboxs)[ind_sort]

                label_nums = img_name.split('_')[-3:]
                label_nums = [num for num in label_nums if num != '0']
                # print(label_nums)
                for idx, label_num in enumerate(label_nums):                    
                    box_xtl, box_ytl, box_xbr, box_ybr = map(int,bboxs[idx])
                    box_area = abs(box_xtl-box_xbr) * abs(box_ytl- box_ybr)

                    with open(label_file,'r') as f:
                        data = csv.DictReader(f)

                        for i in data:
                            location = i['location']
                            label = i['label']
                            label_id = i['label_id']
                            img_dir = img_dir.replace('Z:','DataBase')
                            label_dir = label_dir.replace('Z:','DataBase')

                            values1 = (img_name, img_dir, img_format, img_width, img_height, color_space,
                                       label_name, label_dir, label_format,
                                       location, label, label_id, box_xtl, box_ytl, box_xbr, box_ybr)
                            value_list1.append(values1)
                    # except:
                    #     rm_list.append(label_file)
                if len(value_list1) >= 500:
                    
                    print(value_list1[-1])
                    print(f'{cnt} / {len(img_files)}')
                    doUT.insert_dataset_values(query1_1, value_list1)
                    value_list1 = []
doUT.insert_dataset_values(query1_1, value_list1)

print('done')
# Out:
# ('sharan_test_imageID_1288_GT_3_0_0', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_1288_GT_3_0_0.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_1288_GT_3_0_0', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_1288_GT_3_0_0.csv', 'csv', 'left', 'Adult', 'Thirdmass0058', 0, 181, 342, 640)
# 325 / 6676
# insert 500 done
# ('sharan_test_imageID_4192_GT_0_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_4192_GT_0_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_4192_GT_0_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_4192_GT_0_3_3.csv', 'csv', 'right', 'Adult', 'Secondmass0032', 589, 183, 960, 640)
# 545 / 6676
# insert 500 done
# ('sharan_test_imageID_4324_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_4324_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_4324_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_4324_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Mass0007', 598, 76, 960, 640)
# 673 / 6676
# insert 505 done
# ('sharan_test_imageID_4445_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_4445_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_4445_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_4445_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Secondmass0040', 608, 388, 960, 640)
# 790 / 6676
# insert 505 done
# ('sharan_test_imageID_4596_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_4596_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_4596_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_4596_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0088', 605, 347, 960, 640)
# 939 / 6676
# insert 506 done
# ('sharan_test_imageID_4733_GT_0_0_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_4733_GT_0_0_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_4733_GT_0_0_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_4733_GT_0_0_3.csv', 'csv', 'right', 'Adult', 'Secondmass0049', 605, 121, 960, 640)
# 1073 / 6676
# insert 500 done
# ('sharan_test_imageID_4889_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_4889_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_4889_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_4889_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Secondmass0042', 610, 210, 906, 640)
# 1226 / 6676
# insert 508 done
# ('sharan_test_imageID_5027_GT_3_0_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_5027_GT_3_0_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_5027_GT_3_0_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_5027_GT_3_0_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0097', 604, 173, 960, 640)
# 1358 / 6676
# insert 503 done
# ('sharan_test_imageID_5152_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_5152_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_5152_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_5152_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0084', 612, 127, 960, 640)
# 1483 / 6676
# insert 500 done
# ('sharan_test_imageID_5278_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_5278_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_5278_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_5278_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0078', 615, 160, 860, 640)
# 1603 / 6676
# insert 507 done
# ('sharan_test_imageID_5419_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_5419_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_5419_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_5419_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0070', 576, 153, 960, 640)
# 1741 / 6676
# insert 508 done
# ('sharan_test_imageID_5556_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_5556_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_5556_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_5556_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Secondmass0032', 585, 196, 910, 640)
# 1872 / 6676
# insert 508 done
# ('sharan_test_imageID_7844_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_7844_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_7844_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_7844_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0074', 596, 136, 960, 640)
# 2033 / 6676
# insert 504 done
# ('sharan_test_imageID_8628_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_8628_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_8628_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_8628_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0099', 587, 207, 914, 640)
# 2295 / 6676
# insert 508 done
# ('sharan_test_imageID_9469_GT_0_3_0', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_test_imageID_9469_GT_0_3_0.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_9469_GT_0_3_0', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_test_imageID_9469_GT_0_3_0.csv', 'csv', 'middle', 'Adult', 'Thirdmass0056', 393, 298, 668, 640)
# 2568 / 6676
# insert 500 done
# ('sharan_train_imageID_0126_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_0126_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0126_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_0126_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Mass0018', 586, 173, 861, 640)
# 2742 / 6676
# insert 500 done
# ('sharan_train_imageID_0258_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_0258_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0258_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_0258_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Secondmass0008', 592, 76, 935, 640)
# 2872 / 6676
# insert 505 done
# ('sharan_train_imageID_0386_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_0386_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0386_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_0386_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Mass0009', 568, 143, 954, 640)
# 2999 / 6676
# insert 502 done
# ('sharan_train_imageID_0519_GT_3_0_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_0519_GT_3_0_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0519_GT_3_0_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_0519_GT_3_0_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0033', 567, 106, 960, 640)
# 3129 / 6676
# insert 503 done
# ('sharan_train_imageID_0649_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_0649_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0649_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_0649_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Mass0006', 599, 175, 842, 640)
# 3256 / 6676
# insert 508 done
# ('sharan_train_imageID_0797_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_0797_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0797_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_0797_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0022', 576, 93, 960, 640)
# 3402 / 6676
# insert 501 done
# ('sharan_train_imageID_0937_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_0937_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0937_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_0937_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Mass0004', 580, 184, 900, 640)
# 3538 / 6676
# insert 507 done
# ('sharan_train_imageID_1093_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_1093_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1093_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_1093_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0005', 568, 0, 960, 640)
# 3692 / 6676
# insert 505 done
# ('sharan_train_imageID_1227_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_1227_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1227_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_1227_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0008', 567, 6, 960, 640)
# 3824 / 6676
# insert 506 done
# ('sharan_train_imageID_1358_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_1358_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1358_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_1358_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0042', 616, 179, 960, 640)
# 3953 / 6676
# insert 504 done
# ('sharan_train_imageID_1481_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_1481_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1481_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_1481_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Secondmass0009', 602, 341, 960, 640)
# 4076 / 6676
# insert 507 done
# ('sharan_train_imageID_1605_GT_0_0_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_1605_GT_0_0_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1605_GT_0_0_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_1605_GT_0_0_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0047', 588, 183, 960, 640)
# 4198 / 6676
# insert 500 done
# ('sharan_train_imageID_1732_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_1732_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1732_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_1732_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0021', 555, 100, 960, 640)
# 4325 / 6676
# insert 501 done
# ('sharan_train_imageID_1877_GT_3_3_0', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_1877_GT_3_3_0.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1877_GT_3_3_0', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_1877_GT_3_3_0.csv', 'csv', 'middle', 'Adult', 'Secondmass0012', 282, 72, 710, 640)
# 4467 / 6676
# insert 500 done
# ('sharan_train_imageID_2004_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_2004_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2004_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_2004_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0038', 600, 198, 913, 640)
# 4595 / 6676
# insert 506 done
# ('sharan_train_imageID_2143_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_2143_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2143_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_2143_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0008', 577, 0, 960, 640)
# 4731 / 6676
# insert 502 done
# ('sharan_train_imageID_2278_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_2278_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2278_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_2278_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Secondmass0005', 599, 160, 960, 640)
# 4864 / 6676
# insert 502 done
# ('sharan_train_imageID_2414_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_2414_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2414_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_2414_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Mass0003', 576, 30, 930, 640)
# 4999 / 6676
# insert 502 done
# ('sharan_train_imageID_2553_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_2553_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2553_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_2553_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0028', 598, 129, 960, 640)
# 5134 / 6676
# insert 503 done
# ('sharan_train_imageID_2689_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_2689_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2689_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_2689_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0001', 581, 201, 956, 640)
# 5269 / 6676
# insert 506 done
# ('sharan_train_imageID_2817_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_2817_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2817_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_2817_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0022', 576, 105, 960, 640)
# 5395 / 6676
# insert 504 done
# ('sharan_train_imageID_2956_GT_3_0_0', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_2956_GT_3_0_0.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2956_GT_3_0_0', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_2956_GT_3_0_0.csv', 'csv', 'left', 'Adult', 'Thirdmass0012', 91, 195, 392, 640)
# 5533 / 6676
# insert 500 done
# ('sharan_train_imageID_3094_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_3094_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_3094_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_3094_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0024', 613, 248, 960, 640)
# 5666 / 6676
# insert 508 done
# ('sharan_train_imageID_3234_GT_3_0_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_3234_GT_3_0_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_3234_GT_3_0_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_3234_GT_3_0_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0034', 570, 121, 960, 640)
# 5804 / 6676
# insert 502 done
# ('sharan_train_imageID_3371_GT_0_0_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_3371_GT_0_0_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_3371_GT_0_0_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_3371_GT_0_0_3.csv', 'csv', 'right', 'Adult', 'Secondmass0022', 601, 109, 960, 640)
# 5937 / 6676
# insert 500 done
# ('sharan_train_imageID_3492_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_3492_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_3492_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_3492_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Secondmass0023', 619, 350, 960, 640)
# 6054 / 6676
# insert 507 done
# ('sharan_train_imageID_3644_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_3644_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_3644_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_3644_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0039', 555, 117, 960, 640)
# 6203 / 6676
# insert 508 done
# ('sharan_train_imageID_3783_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_3783_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_3783_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_3783_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Secondmass0009', 576, 108, 960, 640)
# 6339 / 6676
# insert 505 done
# ('sharan_train_imageID_3910_GT_0_3_0', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_3910_GT_0_3_0.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_3910_GT_0_3_0', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_3910_GT_0_3_0.csv', 'csv', 'middle', 'Adult', 'Thirdmass0011', 346, 182, 598, 640)
# 6462 / 6676
# insert 500 done
# ('sharan_train_imageID_4018_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults\\sharan_train_imageID_4018_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_4018_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults/sharan_train_imageID_4018_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0047', 592, 176, 960, 640)
# 6569 / 6676
# insert 503 done
# ('sharan_test_imageID_0024_GT_3_4_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_0024_GT_3_4_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0024_GT_3_4_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_0024_GT_3_4_4.csv', 'csv', 'right', 'EverydayObject', 'Ramy02', 614, 369, 748, 469)
# 10 / 1420
# insert 501 done
# ('sharan_test_imageID_0126_GT_3_4_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_0126_GT_3_4_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0126_GT_3_4_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_0126_GT_3_4_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0098', 564, 36, 960, 640)
# 69 / 1420
# insert 506 done
# ('sharan_test_imageID_0495_GT_4_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_0495_GT_4_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0495_GT_4_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_0495_GT_4_3_3.csv', 'csv', 'right', 'Adult', 'Secondmass0048', 583, 77, 960, 640)
# 126 / 1420
# insert 503 done
# ('sharan_test_imageID_0799_GT_3_4_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_0799_GT_3_4_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0799_GT_3_4_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_0799_GT_3_4_3.csv', 'csv', 'right', 'Adult', 'Secondmass0032', 601, 169, 960, 640)
# 183 / 1420
# insert 508 done
# ('sharan_test_imageID_1169_GT_3_3_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_1169_GT_3_3_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_1169_GT_3_3_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_1169_GT_3_3_4.csv', 'csv', 'right', 'EverydayObject', 'WashMachine', 593, 278, 960, 576)
# 241 / 1420
# insert 507 done
# ('sharan_test_imageID_1683_GT_3_3_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_1683_GT_3_3_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_1683_GT_3_3_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_1683_GT_3_3_4.csv', 'csv', 'right', 'EverydayObject', 'Keyboard_01', 668, 419, 725, 519)
# 299 / 1420
# insert 507 done
# ('sharan_test_imageID_2446_GT_3_4_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_2446_GT_3_4_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_2446_GT_3_4_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_2446_GT_3_4_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0076', 579, 68, 960, 640)
# 357 / 1420
# insert 507 done
# ('sharan_test_imageID_7691_GT_3_4_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_7691_GT_3_4_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_7691_GT_3_4_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_7691_GT_3_4_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0064', 580, 143, 960, 640)
# 416 / 1420
# insert 506 done
# ('sharan_test_imageID_7799_GT_4_3_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_7799_GT_4_3_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_7799_GT_4_3_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_7799_GT_4_3_4.csv', 'csv', 'right', 'EverydayObject', 'Keyboard_01', 637, 419, 725, 519)
# 473 / 1420
# insert 503 done
# ('sharan_test_imageID_7897_GT_3_3_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_7897_GT_3_3_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_7897_GT_3_3_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_7897_GT_3_3_4.csv', 'csv', 'right', 'EverydayObject', 'Panel', 606, 409, 798, 624)
# 531 / 1420
# insert 502 done
# ('sharan_test_imageID_8010_GT_3_4_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_8010_GT_3_4_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_8010_GT_3_4_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_8010_GT_3_4_4.csv', 'csv', 'right', 'EverydayObject', 'Pflanze', 621, 230, 960, 534)
# 588 / 1420
# insert 503 done
# ('sharan_test_imageID_8132_GT_3_4_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_8132_GT_3_4_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_8132_GT_3_4_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_8132_GT_3_4_4.csv', 'csv', 'right', 'EverydayObject', 'Inlineskate', 605, 399, 744, 522)
# 645 / 1420
# insert 508 done
# ('sharan_test_imageID_8242_GT_4_3_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_8242_GT_4_3_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_8242_GT_4_3_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_8242_GT_4_3_4.csv', 'csv', 'right', 'EverydayObject', 'pillow1_main', 620, 390, 705, 466)
# 703 / 1420
# insert 502 done
# ('sharan_test_imageID_8341_GT_3_4_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_8341_GT_3_4_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_8341_GT_3_4_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_8341_GT_3_4_4.csv', 'csv', 'right', 'EverydayObject', 'BoxAroundBottles', 604, 360, 761, 520)
# 760 / 1420
# insert 508 done
# ('sharan_test_imageID_8490_GT_3_3_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_8490_GT_3_3_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_8490_GT_3_3_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_8490_GT_3_3_4.csv', 'csv', 'right', 'EverydayObject', 'Ramy02', 612, 368, 743, 466)
# 816 / 1420
# insert 504 done
# ('sharan_test_imageID_8600_GT_3_4_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_8600_GT_3_4_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_8600_GT_3_4_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_8600_GT_3_4_3.csv', 'csv', 'right', 'Adult', 'Secondmass0043', 570, 11, 960, 640)
# 875 / 1420
# insert 501 done
# ('sharan_test_imageID_8722_GT_4_3_0', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_8722_GT_4_3_0.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_8722_GT_4_3_0', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_8722_GT_4_3_0.csv', 'csv', 'middle', 'Adult', 'Thirdmass0051', 316, 26, 673, 640)
# 935 / 1420
# insert 500 done
# ('sharan_test_imageID_8823_GT_4_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_8823_GT_4_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_8823_GT_4_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_8823_GT_4_3_3.csv', 'csv', 'right', 'Adult', 'Mass0022', 566, 71, 960, 640)
# 993 / 1420
# insert 507 done
# ('sharan_test_imageID_8923_GT_3_4_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_8923_GT_3_4_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_8923_GT_3_4_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_8923_GT_3_4_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0066', 590, 135, 960, 640)
# 1050 / 1420
# insert 503 done
# ('sharan_test_imageID_9046_GT_3_4_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_9046_GT_3_4_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_9046_GT_3_4_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_9046_GT_3_4_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0071', 575, 52, 960, 640)
# 1107 / 1420
# insert 503 done
# ('sharan_test_imageID_9155_GT_4_4_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_9155_GT_4_4_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_9155_GT_4_4_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_9155_GT_4_4_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0067', 554, 100, 960, 640)
# 1165 / 1420
# insert 507 done
# ('sharan_test_imageID_9270_GT_3_3_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_9270_GT_3_3_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_9270_GT_3_3_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_9270_GT_3_3_4.csv', 'csv', 'right', 'EverydayObject', 'pillow3_main', 621, 384, 735, 521)
# 1222 / 1420
# insert 508 done
# ('sharan_test_imageID_9372_GT_4_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_9372_GT_4_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_9372_GT_4_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_9372_GT_4_3_3.csv', 'csv', 'right', 'Adult', 'Secondmass0030', 587, 142, 960, 640)
# 1280 / 1420
# insert 502 done
# ('sharan_test_imageID_9487_GT_3_3_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_9487_GT_3_3_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_9487_GT_3_3_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_9487_GT_3_3_4.csv', 'csv', 'right', 'EverydayObject', 'Stereo textured mesh', 628, 352, 774, 540)
# 1337 / 1420
# insert 503 done
# ('sharan_test_imageID_9588_GT_4_4_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_objects\\sharan_test_imageID_9588_GT_4_4_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_9588_GT_4_4_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_objects/sharan_test_imageID_9588_GT_4_4_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0081', 565, 42, 960, 640)
# 1394 / 1420
# insert 508 done
# ('sharan_test_imageID_0100_GT_2_2_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_test_imageID_0100_GT_2_2_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0100_GT_2_2_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_test_imageID_0100_GT_2_2_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0086', 388, 204, 960, 640)
# 31 / 3600
# insert 508 done
# ('sharan_test_imageID_0241_GT_2_3_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_test_imageID_0241_GT_2_3_2.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0241_GT_2_3_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_test_imageID_0241_GT_2_3_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Asian_boy_02', 658, 287, 849, 582)
# 90 / 3600
# insert 506 done
# ('sharan_test_imageID_0382_GT_3_2_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_test_imageID_0382_GT_3_2_1.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0382_GT_3_2_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_test_imageID_0382_GT_3_2_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babymh', 390, 262, 777, 625)
# 148 / 3600
# insert 507 done
# ('sharan_test_imageID_0514_GT_1_3_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_test_imageID_0514_GT_1_3_1.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0514_GT_1_3_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_test_imageID_0514_GT_1_3_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babymh', 357, 136, 624, 640)
# 205 / 3600
# insert 503 done
# ('sharan_test_imageID_0664_GT_1_3_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_test_imageID_0664_GT_1_3_2.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0664_GT_1_3_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_test_imageID_0664_GT_1_3_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Caucassian_girl_01', 646, 282, 873, 575)
# 262 / 3600
# insert 508 done
# ('sharan_test_imageID_0793_GT_3_1_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_test_imageID_0793_GT_3_1_2.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0793_GT_3_1_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_test_imageID_0793_GT_3_1_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Caucassian_girl_01', 431, 399, 515, 553)
# 319 / 3600
# insert 508 done
# ('sharan_test_imageID_1036_GT_3_1_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_test_imageID_1036_GT_3_1_2.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_1036_GT_3_1_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_test_imageID_1036_GT_3_1_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Caucassian_girl_01', 419, 414, 521, 614)
# 378 / 3600
# insert 501 done
# ('sharan_test_imageID_1303_GT_2_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_test_imageID_1303_GT_2_3_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_1303_GT_2_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_test_imageID_1303_GT_2_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0054', 160, 139, 960, 640)
# 438 / 3600
# insert 505 done
# ('sharan_train_imageID_0057_GT_3_2_0', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_0057_GT_3_2_0.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0057_GT_3_2_0', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_0057_GT_3_2_0.csv', 'csv', 'middle', 'OccupiedChildSeat', 'African_girl_train_02', 391, 291, 528, 598)
# 518 / 3600
# insert 500 done
# ('sharan_train_imageID_0171_GT_3_1_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_0171_GT_3_1_2.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0171_GT_3_1_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_0171_GT_3_1_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'African_girl_train_02', 432, 263, 832, 626)
# 625 / 3600
# insert 508 done
# ('sharan_train_imageID_0289_GT_0_2_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_0289_GT_0_2_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0289_GT_0_2_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_0289_GT_0_2_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0005', 551, 0, 960, 640)
# 729 / 3600
# insert 501 done
# ('sharan_train_imageID_0406_GT_1_3_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_0406_GT_1_3_2.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0406_GT_1_3_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_0406_GT_1_3_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'African_girl_train_02', 365, 188, 828, 640)
# 837 / 3600
# insert 501 done
# ('sharan_train_imageID_0520_GT_3_1_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_0520_GT_3_1_2.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0520_GT_3_1_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_0520_GT_3_1_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Caucassian_boy_train_02', 380, 377, 570, 640)
# 942 / 3600
# insert 500 done
# ('sharan_train_imageID_0633_GT_1_1_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_0633_GT_1_1_2.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0633_GT_1_1_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_0633_GT_1_1_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Asian_girl_train_01', 384, 384, 580, 616)
# 1043 / 3600
# insert 502 done
# ('sharan_train_imageID_0743_GT_2_3_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_0743_GT_2_3_1.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0743_GT_2_3_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_0743_GT_2_3_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Baby0005', 606, 378, 884, 640)
# 1141 / 3600
# insert 501 done
# ('sharan_train_imageID_0857_GT_2_3_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_0857_GT_2_3_1.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0857_GT_2_3_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_0857_GT_2_3_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babypink', 661, 386, 814, 538)
# 1252 / 3600
# insert 505 done
# ('sharan_train_imageID_0975_GT_3_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_0975_GT_3_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_0975_GT_3_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_0975_GT_3_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0004', 604, 258, 943, 640)
# 1359 / 3600
# insert 501 done
# ('sharan_train_imageID_1090_GT_3_1_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_1090_GT_3_1_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1090_GT_3_1_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_1090_GT_3_1_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0029', 359, 302, 587, 640)
# 1466 / 3600
# insert 503 done
# ('sharan_train_imageID_1189_GT_2_1_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_1189_GT_2_1_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1189_GT_2_1_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_1189_GT_2_1_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0028', 359, 302, 587, 640)
# 1560 / 3600
# insert 508 done
# ('sharan_train_imageID_1305_GT_3_1_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_1305_GT_3_1_2.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1305_GT_3_1_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_1305_GT_3_1_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Asian_boy_train_02', 380, 377, 570, 640)
# 1663 / 3600
# insert 505 done
# ('sharan_train_imageID_1412_GT_2_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_1412_GT_2_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1412_GT_2_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_1412_GT_2_3_3.csv', 'csv', 'right', 'Adult', 'Mass0002', 589, 165, 960, 640)
# 1765 / 3600
# insert 500 done
# ('sharan_train_imageID_1528_GT_3_3_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_1528_GT_3_3_1.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1528_GT_3_3_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_1528_GT_3_3_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babypink', 690, 414, 863, 614)
# 1872 / 3600
# insert 500 done
# ('sharan_train_imageID_1647_GT_2_3_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_1647_GT_2_3_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1647_GT_2_3_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_1647_GT_2_3_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0048', 580, 59, 902, 640)
# 1981 / 3600
# insert 507 done
# ('sharan_train_imageID_1764_GT_2_3_0', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_1764_GT_2_3_0.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1764_GT_2_3_0', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_1764_GT_2_3_0.csv', 'csv', 'middle', 'Adult', 'Thirdmass0011', 367, 189, 645, 640)
# 2090 / 3600
# insert 502 done
# ('sharan_train_imageID_1876_GT_3_3_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_1876_GT_3_3_1.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_1876_GT_3_3_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_1876_GT_3_3_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babypink', 688, 411, 864, 614)
# 2197 / 3600
# insert 503 done
# ('sharan_train_imageID_2000_GT_2_1_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_2000_GT_2_1_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2000_GT_2_1_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_2000_GT_2_1_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0021', 431, 393, 516, 553)
# 2314 / 3600
# insert 506 done
# ('sharan_train_imageID_2107_GT_0_1_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_2107_GT_0_1_1.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2107_GT_0_1_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_2107_GT_0_1_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Baby0005', 425, 396, 514, 544)
# 2413 / 3600
# insert 503 done
# ('sharan_train_imageID_2225_GT_1_0_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_2225_GT_1_0_1.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2225_GT_1_0_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_2225_GT_1_0_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Baby0006', 143, 397, 311, 546)
# 2522 / 3600
# insert 502 done
# ('sharan_train_imageID_2327_GT_1_2_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_2327_GT_1_2_1.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2327_GT_1_2_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_2327_GT_1_2_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Baby0005', 396, 293, 527, 604)
# 2615 / 3600
# insert 503 done
# ('sharan_train_imageID_2434_GT_2_0_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_2434_GT_2_0_1.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2434_GT_2_0_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_2434_GT_2_0_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Baby0005', 669, 409, 821, 597)
# 2722 / 3600
# insert 501 done
# ('sharan_train_imageID_2544_GT_2_1_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_2544_GT_2_1_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2544_GT_2_1_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_2544_GT_2_1_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0036', 428, 386, 519, 559)
# 2822 / 3600
# insert 504 done
# ('sharan_train_imageID_2650_GT_2_1_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_2650_GT_2_1_1.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2650_GT_2_1_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_2650_GT_2_1_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babypink', 435, 397, 515, 550)
# 2924 / 3600
# insert 508 done
# ('sharan_train_imageID_2765_GT_2_1_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_2765_GT_2_1_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2765_GT_2_1_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_2765_GT_2_1_3.csv', 'csv', 'right', 'Adult', 'Secondmass0016', 348, 376, 572, 640)
# 3034 / 3600
# insert 502 done
# ('sharan_train_imageID_2877_GT_2_3_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_2877_GT_2_3_2.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2877_GT_2_3_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_2877_GT_2_3_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Asian_girl_train_01', 321, 0, 786, 640)
# 3136 / 3600
# insert 503 done
# ('sharan_train_imageID_2981_GT_1_1_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_2981_GT_1_1_3.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_2981_GT_1_1_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_2981_GT_1_1_3.csv', 'csv', 'right', 'Adult', 'Mass0018', 359, 302, 587, 640)
# 3234 / 3600
# insert 504 done
# ('sharan_train_imageID_3061_GT_1_1_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_3061_GT_1_1_1.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_3061_GT_1_1_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_3061_GT_1_1_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Baby0005', 431, 396, 516, 550)
# 3307 / 3600
# insert 502 done
# ('sharan_train_imageID_3138_GT_2_2_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_3138_GT_2_2_2.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_3138_GT_2_2_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_3138_GT_2_2_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Asian_boy_train_02', 605, 279, 876, 604)
# 3376 / 3600
# insert 502 done
# ('sharan_train_imageID_3210_GT_1_3_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_3210_GT_1_3_1.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_3210_GT_1_3_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_3210_GT_1_3_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babypink', 303, 73, 679, 640)
# 3441 / 3600
# insert 505 done
# ('sharan_train_imageID_3276_GT_1_1_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_3276_GT_1_1_2.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_3276_GT_1_1_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_3276_GT_1_1_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'African_girl_train_02', 348, 376, 572, 640)
# 3504 / 3600
# insert 501 done
# ('sharan_train_imageID_3351_GT_2_2_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats\\sharan_train_imageID_3351_GT_2_2_2.png', 'png', 960, 640, 'RGB', 'sharan_train_imageID_3351_GT_2_2_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats/sharan_train_imageID_3351_GT_2_2_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Caucassian_girl_train_02', 605, 279, 843, 604)
# 3573 / 3600
# insert 505 done
# ('sharan_test_imageID_0042_GT_2_3_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0042_GT_2_3_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0042_GT_2_3_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0042_GT_2_3_4.csv', 'csv', 'right', 'EverydayObject', 'pillow3_main', 621, 407, 721, 521)
# 34 / 1672
# insert 504 done
# ('sharan_test_imageID_0103_GT_3_4_2', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0103_GT_3_4_2.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0103_GT_3_4_2', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0103_GT_3_4_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Caucassian_girl_01', 598, 220, 912, 597)
# 90 / 1672
# insert 504 done
# ('sharan_test_imageID_0178_GT_2_2_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0178_GT_2_2_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0178_GT_2_2_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0178_GT_2_2_4.csv', 'csv', 'right', 'EverydayObject', 'Saw', 647, 403, 746, 588)
# 146 / 1672
# insert 504 done
# ('sharan_test_imageID_0255_GT_1_4_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0255_GT_1_4_1.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0255_GT_1_4_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0255_GT_1_4_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Baby0004', 409, 351, 550, 539)
# 202 / 1672
# insert 504 done
# ('sharan_test_imageID_0325_GT_1_3_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0325_GT_1_3_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0325_GT_1_3_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0325_GT_1_3_4.csv', 'csv', 'right', 'EverydayObject', 'Pflanze', 315, 121, 770, 640)
# 258 / 1672
# insert 504 done
# ('sharan_test_imageID_0395_GT_2_4_1', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0395_GT_2_4_1.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0395_GT_2_4_1', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0395_GT_2_4_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Baby0004', 665, 398, 780, 551)
# 314 / 1672
# insert 504 done
# ('sharan_test_imageID_0466_GT_4_1_4', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0466_GT_4_1_4.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0466_GT_4_1_4', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0466_GT_4_1_4.csv', 'csv', 'right', 'EverydayObject', 'Nektar Panorama P6', 359, 302, 759, 640)
# 370 / 1672
# insert 504 done
# ('sharan_test_imageID_0543_GT_4_1_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0543_GT_4_1_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0543_GT_4_1_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0543_GT_4_1_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0061', 380, 377, 570, 640)
# 426 / 1672
# insert 504 done
# ('sharan_test_imageID_0624_GT_4_1_3', 'DataBase\\sviro_uncertainty\\data\\RGB\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0624_GT_4_1_3.png', 'png', 960, 640, 'RGB', 'sharan_test_imageID_0624_GT_4_1_3', 'DataBase/sviro_uncertainty/data/RGB/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0624_GT_4_1_3.csv', 'csv', 'right', 'Adult', 'Thirdmass0096', 428, 397, 519, 542)
# 482 / 1672
# insert 504 done
# ...
# 235 / 1672
# insert 504 done
# ('sharan_test_imageID_0366_GT_1_4_1', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0366_GT_1_4_1.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_0366_GT_1_4_1', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0366_GT_1_4_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Baby0004', 349, 431, 538, 497)
# 291 / 1672
# insert 504 done
# ('sharan_test_imageID_0437_GT_4_1_1', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0437_GT_4_1_1.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_0437_GT_4_1_1', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0437_GT_4_1_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babyblue', 359, 302, 587, 640)
# 347 / 1672
# insert 504 done
# ('sharan_test_imageID_0512_GT_3_4_2', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0512_GT_3_4_2.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_0512_GT_3_4_2', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0512_GT_3_4_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Asian_boy_01', 646, 299, 857, 572)
# 403 / 1672
# insert 504 done
# ('sharan_test_imageID_0595_GT_3_1_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0595_GT_3_1_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_0595_GT_3_1_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0595_GT_3_1_4.csv', 'csv', 'right', 'EverydayObject', 'polySurface798', 384, 384, 580, 616)
# 459 / 1672
# insert 504 done
# ('sharan_test_imageID_0661_GT_1_4_2', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0661_GT_1_4_2.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_0661_GT_1_4_2', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0661_GT_1_4_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'African_girl_01', 410, 369, 537, 468)
# 515 / 1672
# insert 504 done
# ('sharan_test_imageID_0746_GT_4_1_2', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0746_GT_4_1_2.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_0746_GT_4_1_2', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0746_GT_4_1_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Caucassian_girl_01', 365, 373, 580, 623)
# 571 / 1672
# insert 504 done
# ('sharan_test_imageID_0829_GT_4_3_1', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0829_GT_4_3_1.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_0829_GT_4_3_1', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0829_GT_4_3_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babyblue', 683, 413, 864, 615)
# 627 / 1672
# insert 504 done
# ('sharan_test_imageID_0892_GT_4_4_2', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0892_GT_4_4_2.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_0892_GT_4_4_2', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0892_GT_4_4_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Asian_boy_02', 617, 263, 832, 626)
# 683 / 1672
# insert 504 done
# ('sharan_test_imageID_0954_GT_4_2_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_0954_GT_4_2_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_0954_GT_4_2_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_0954_GT_4_2_4.csv', 'csv', 'right', 'EverydayObject', 'Pflanze', 405, 279, 542, 488)
# 739 / 1672
# insert 504 done
# ('sharan_test_imageID_1026_GT_2_4_2', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_1026_GT_2_4_2.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_1026_GT_2_4_2', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_1026_GT_2_4_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Caucassian_girl_01', 129, 277, 863, 602)
# 795 / 1672
# insert 504 done
# ('sharan_test_imageID_1110_GT_2_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_1110_GT_2_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_1110_GT_2_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_1110_GT_2_4_4.csv', 'csv', 'right', 'EverydayObject', 'suitcase-sketchfab-texturing-challenge', 441, 327, 503, 514)
# 851 / 1672
# insert 504 done
# ('sharan_test_imageID_1178_GT_1_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_1178_GT_1_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_1178_GT_1_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_1178_GT_1_4_4.csv', 'csv', 'right', 'EverydayObject', 'Amp', 431, 381, 519, 472)
# 907 / 1672
# insert 504 done
# ('sharan_test_imageID_1258_GT_2_4_2', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_1258_GT_2_4_2.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_1258_GT_2_4_2', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_1258_GT_2_4_2.csv', 'csv', 'right', 'OccupiedChildSeat', 'Asian_boy_01', 134, 245, 862, 565)
# 963 / 1672
# insert 504 done
# ('sharan_test_imageID_1329_GT_1_3_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_1329_GT_1_3_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_1329_GT_1_3_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_1329_GT_1_3_4.csv', 'csv', 'right', 'EverydayObject', 'cadre_lowpoly', 604, 374, 779, 536)
# 1019 / 1672
# insert 504 done
# ('sharan_test_imageID_1389_GT_2_4_3', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_1389_GT_2_4_3.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_1389_GT_2_4_3', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_1389_GT_2_4_3.csv', 'csv', 'right', 'Adult', 'Secondmass0049', 140, 147, 960, 640)
# 1075 / 1672
# insert 504 done
# ('sharan_test_imageID_1450_GT_4_2_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_1450_GT_4_2_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_1450_GT_4_2_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_1450_GT_4_2_4.csv', 'csv', 'right', 'EverydayObject', 'Panel', 360, 219, 578, 596)
# 1131 / 1672
# insert 504 done
# ('sharan_test_imageID_1533_GT_3_2_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_1533_GT_3_2_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_1533_GT_3_2_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_1533_GT_3_2_4.csv', 'csv', 'right', 'EverydayObject', 'Hammer_LP', 652, 406, 733, 519)
# 1187 / 1672
# insert 504 done
# ('sharan_test_imageID_1632_GT_1_2_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_1632_GT_1_2_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_1632_GT_1_2_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_1632_GT_1_2_4.csv', 'csv', 'right', 'EverydayObject', 'Inlineskate', 383, 246, 573, 571)
# 1243 / 1672
# insert 504 done
# ('sharan_test_imageID_1770_GT_2_4_1', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_1770_GT_2_4_1.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_1770_GT_2_4_1', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_1770_GT_2_4_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babymh', 128, 277, 814, 602)
# 1299 / 1672
# insert 504 done
# ('sharan_test_imageID_1909_GT_2_4_1', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_1909_GT_2_4_1.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_1909_GT_2_4_1', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_1909_GT_2_4_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babyblue', 126, 277, 865, 615)
# 1355 / 1672
# insert 504 done
# ('sharan_test_imageID_2047_GT_4_2_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_2047_GT_4_2_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_2047_GT_4_2_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_2047_GT_4_2_4.csv', 'csv', 'right', 'EverydayObject', 'Saw', 383, 246, 573, 546)
# 1411 / 1672
# insert 504 done
# ('sharan_test_imageID_2192_GT_1_4_1', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_2192_GT_1_4_1.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_2192_GT_1_4_1', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_2192_GT_1_4_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babymh', 404, 392, 521, 564)
# 1467 / 1672
# insert 504 done
# ('sharan_test_imageID_2309_GT_2_1_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_2309_GT_2_1_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_2309_GT_2_1_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_2309_GT_2_1_4.csv', 'csv', 'right', 'EverydayObject', 'pillow1_main', 359, 302, 587, 640)
# 1523 / 1672
# insert 504 done
# ('sharan_test_imageID_2429_GT_1_3_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_2429_GT_1_3_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_2429_GT_1_3_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_2429_GT_1_3_4.csv', 'csv', 'right', 'EverydayObject', 'Bottle_main', 612, 461, 719, 490)
# 1579 / 1672
# insert 504 done
# ('sharan_test_imageID_2590_GT_4_4_1', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\adults_and_seats_and_objects\\sharan_test_imageID_2590_GT_4_4_1.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_2590_GT_4_4_1', 'DataBase/sviro_uncertainty/data/IR/labeldata/adults_and_seats_and_objects/sharan_test_imageID_2590_GT_4_4_1.csv', 'csv', 'right', 'OccupiedInfantSeat', 'Babyblue', 660, 397, 781, 553)
# 1635 / 1672
# insert 504 done
# ('sharan_test_imageID_0207_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_0207_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_0207_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_0207_GT_4_4_4.csv', 'csv', 'right', 'EverydayObject', 'Nektar Panorama P6', 602, 444, 759, 496)
# 19 / 1055
# insert 504 done
# ('sharan_test_imageID_6046_GT_4_4_0', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_6046_GT_4_4_0.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_6046_GT_4_4_0', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_6046_GT_4_4_0.csv', 'csv', 'middle', 'EverydayObject', 'Violino', 398, 417, 526, 640)
# 83 / 1055
# insert 501 done
# ('sharan_test_imageID_6234_GT_4_0_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_6234_GT_4_0_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_6234_GT_4_0_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_6234_GT_4_0_4.csv', 'csv', 'right', 'EverydayObject', 'lamp_gas_HP', 653, 352, 743, 513)
# 176 / 1055
# insert 502 done
# ('sharan_test_imageID_6474_GT_4_4_0', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_6474_GT_4_4_0.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_6474_GT_4_4_0', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_6474_GT_4_4_0.csv', 'csv', 'middle', 'EverydayObject', 'Keyboard_01', 448, 419, 494, 518)
# 275 / 1055
# insert 501 done
# ('sharan_test_imageID_6687_GT_0_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_6687_GT_0_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_6687_GT_0_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_6687_GT_0_4_4.csv', 'csv', 'right', 'EverydayObject', 'pillow2_main', 617, 416, 695, 471)
# 374 / 1055
# insert 501 done
# ('sharan_test_imageID_6902_GT_4_4_0', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_6902_GT_4_4_0.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_6902_GT_4_4_0', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_6902_GT_4_4_0.csv', 'csv', 'middle', 'EverydayObject', 'Inlineskate', 396, 393, 532, 517)
# 481 / 1055
# insert 503 done
# ('sharan_test_imageID_7114_GT_4_0_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_7114_GT_4_0_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_7114_GT_4_0_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_7114_GT_4_0_4.csv', 'csv', 'right', 'EverydayObject', 'Amp', 630, 417, 739, 495)
# 574 / 1055
# insert 502 done
# ('sharan_test_imageID_7327_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_7327_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_7327_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_7327_GT_4_4_4.csv', 'csv', 'right', 'EverydayObject', 'Bottle_main', 613, 445, 720, 509)
# 671 / 1055
# insert 508 done
# ('sharan_test_imageID_7505_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_7505_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_7505_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_7505_GT_4_4_4.csv', 'csv', 'right', 'EverydayObject', 'Hammer_LP', 605, 438, 738, 504)
# 764 / 1055
# insert 502 done
# ('sharan_test_imageID_7810_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_7810_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_7810_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_7810_GT_4_4_4.csv', 'csv', 'right', 'EverydayObject', 'Panel', 606, 409, 798, 624)
# 839 / 1055
# insert 500 done
# ('sharan_test_imageID_8277_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_8277_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_8277_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_8277_GT_4_4_4.csv', 'csv', 'right', 'EverydayObject', 'Bottle_main', 612, 461, 719, 490)
# 896 / 1055
# insert 508 done
# ('sharan_test_imageID_8676_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_8676_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_8676_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_8676_GT_4_4_4.csv', 'csv', 'right', 'EverydayObject', 'WashMachine', 590, 278, 960, 576)
# 952 / 1055
# insert 504 done
# ('sharan_test_imageID_9161_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9161_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9161_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9161_GT_4_4_4.csv', 'csv', 'right', 'EverydayObject', 'Ramy02', 612, 368, 743, 466)
# 1008 / 1055
# insert 504 done
# insert 409 done
# done

# %%
value_list2 = []
project_id = None
colors = ['RGB','IR']

for color_space in colors:
    label_path = f'Z:\\sviro_uncertainty\\data\\{color_space}\\labeldata'
    label_ids = os.listdir(label_path)
    for label_id in label_ids:
        label_files = os.listdir(os.path.join(label_path,label_id))  
        for cnt, label_file in enumerate(label_files):
            label_dir = os.path.join(label_path,label_id,label_file)
            # print(label_dir)
            img_dir = '/'.join(label_file.replace('label','raw').replace('csv','png').split('\\')[-7:])
            img_load = label_file.replace('label','raw').replace('csv','png')
            # print(img_load)
            img_file = os.path.basename(img_dir)
            img_name, img_format = os.path.splitext(img_file)
            img_format = img_format.replace('.','')
            label_name, label_format = os.path.splitext(os.path.basename(label_file))
            label_format = label_format.replace('.','')

            try:
                image = cv2.imread(img)
                
                img_width = image.shape[1]
                img_height = image.shape[0]
            except Exception as e:
                error_list.append(label_dir)
                print(label_dir, e)
                continue

            with open(label_dir,'r') as f:
                data = csv.DictReader(f)
                for idx, i in enumerate(data):
                    location = i['location']
                    label = i['label']
                    label = i['label_id']
                    landmark = i['landmark']
                    if label != 'EverydayObject':
                        img_dir = img_dir.replace('Z:','DataBase')
                        label_dir = label_dir.replace('Z:','DataBase')
                        values2 = (img_name, img_dir, img_format, img_width, img_height, color_space,
                                  label_name, label_dir, label_format,
                                  location, label, label_id,landmark)
                        value_list2.append(values2)
                        if len(value_list2) >= 300:
                            print(value_list1[-2])
                            print(f'{cnt} / {len(label_files)}')
                            doUT.insert_dataset_values(query2_1, value_list2)
                            value_list2 = []
doUT.insert_dataset_values(query2_1, value_list2)
print('done')
# Out:
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 256 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 508 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 676 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 844 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1027 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1206 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1371 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1537 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1712 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1882 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2078 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2324 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2568 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2765 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2931 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3106 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3272 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3455 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3635 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3813 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3987 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 4145 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 4319 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 4494 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 4670 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 4846 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 5017 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 5195 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 5365 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 5540 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 5719 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 5890 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 6053 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 6233 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 6402 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 6564 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 35 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 137 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 238 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 339 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 442 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 544 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 645 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 746 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 847 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 951 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1053 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1154 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1256 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1357 / 1420
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 37 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 140 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 241 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 342 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 446 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 584 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 729 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 875 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1025 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1169 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1315 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1467 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1606 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1751 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1904 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2051 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2204 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2355 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2498 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2642 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2791 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2932 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3083 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3224 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3346 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3459 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3571 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 75 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 175 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 275 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 375 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 475 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 575 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 675 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 775 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 875 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 975 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1075 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1175 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1275 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1375 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1475 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1575 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 116 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 249 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 385 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 523 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 657 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 787 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 894 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 994 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 101 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 366 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 577 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 743 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 916 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1089 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1275 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1440 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1603 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1775 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1947 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2179 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2424 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2654 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2832 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3001 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3171 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3348 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3529 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3709 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3879 / 6676
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 4051 / 6676
# insert 300 done
# ...
# 1374 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1522 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1667 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1813 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1962 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2113 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2263 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2411 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2557 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2705 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2848 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 2996 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3141 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3276 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3391 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 3502 / 3600
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 15 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 115 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 215 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 315 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 415 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 515 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 615 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 715 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 815 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 915 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1015 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1115 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1215 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1315 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1415 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1515 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1615 / 1672
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 43 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 169 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 303 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 440 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 575 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 708 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 834 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 934 / 1055
# insert 300 done
# ('sharan_test_imageID_9620_GT_4_4_4', 'DataBase\\sviro_uncertainty\\data\\IR\\rawdata\\objects\\sharan_test_imageID_9620_GT_4_4_4.png', 'png', 960, 640, 'IR', 'sharan_test_imageID_9620_GT_4_4_4', 'DataBase/sviro_uncertainty/data/IR/labeldata/objects/sharan_test_imageID_9620_GT_4_4_4.csv', 'csv', 'middle', 'EverydayObject', '037_Vray', 653, 352, 743, 513)
# 1034 / 1055
# insert 300 done
# insert 60 done
# done

# %%
doUT.connect_end()
# Out:
# SQL connection closed
